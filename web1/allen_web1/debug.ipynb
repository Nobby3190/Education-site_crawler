# %%
from monitor import monitor
import sys
import traceback
import os
from selenium import webdriver
import time
import requests
from bs4 import BeautifulSoup as bs
from selenium.webdriver.chrome.options import Options
from tqdm import tqdm
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime
import numpy as np

# %%
def urlandcrawl():
    try:
        page_list = ["career",'education','living','health','senior','pets','language','design','creative-industry','technology','business','investment-finance']
        options = webdriver.ChromeOptions()
        options.add_argument("--headless")
        driver = webdriver.Chrome(chrome_options = options, executable_path = "/Users/t3019ein/Desktop/chromedriver")
        driver.implicitly_wait(3)
        urls_list = []
        for x in page_list:
            for i in range(1,15):
                raw_page = driver.get(f"https://ggc.hkxf.com.tw/category/{x}/{i}")
                time.sleep(2)
                for j in range(1,11):
                    urls = driver.find_elements_by_xpath(f"//*[@id='CourseContainer']/div[{j}]/div[2]/a")
                    for k in urls:
                        href = k.get_attribute("href")
                        urls_list.append(href)
#     except TypeError as e:
#         print("抓網頁有出錯")
#     finally:
#         return urls_list
# def main(urls_list):
#     options = webdriver.ChromeOptions()
    # #         options.add_argument("--headless")
#     driver = webdriver.Chrome(chrome_options = options, executable_path = "/Users/t3019ein/Desktop/chromedriver")
#     driver.implicitly_wait(3)
    # time.sleep(3)
        item_list = []
#     urls_list = url()
#     try:
        for z in urls_list:
            dic = {}
            driver.get(z)
            title = driver.find_elements_by_xpath("//div[@class='pr-2 pl-2'][2]/h2[@class='mt-3 mb-2 font-weight-bold']")
            driver.implicitly_wait(3)
        #           課程標題
            for a in title:
                dic["title"] = a.text.strip().replace("⭐","").replace("🏠","").replace("《","").replace("》","").replace("【","").replace("】","").replace("—","").replace("~","").replace("│","").replace("®","")
            during = driver.find_elements_by_xpath("//ul[@class='course-info-list mt-20 mt-4 ml-0 pl-0']/li[1]/span[@class='course-info-details text-gray-darkgray']")
            driver.implicitly_wait(3)
        #           課程時程
            for c in during:
                dic["during"] = c.text.strip()
            hours = driver.find_elements_by_xpath("//ul[@class='course-info-list mt-20 mt-4 ml-0 pl-0']/li[3]/span[@class='course-info-details text-gray-darkgray']")
            driver.implicitly_wait(3)
        #           課程時數
            for d in hours:
                dic["hours"] = d.text.strip().replace("hr","")
            location = driver.find_elements_by_xpath("//ul[@class='course-info-list mt-20 mt-4 ml-0 pl-0']/li[5]/a/span[@class='course-info-details']")
            driver.implicitly_wait(3)
        # #           課程地點
            for e in location:
                dic["location"] = e.text.strip()
            price = driver.find_elements_by_xpath("//ul[@class='course-info-list mt-20 mt-4 ml-0 pl-0']/li[6]/span[@class='course-info-details f-10 text-gray-darkgray']")
            driver.implicitly_wait(3)
        # #           課程價格
            for f in price:
                dic["price"] = f.text.strip().replace("NTD$","")
            coursetime = driver.find_elements_by_xpath("//ul[@class='course-info-list mt-20 mt-4 ml-0 pl-0']/li[2]/span[@class='course-info-details align-middle text-gray-darkgray']")
            driver.implicitly_wait(3)
#             課程時間
            for g in coursetime:
                dic['time'] = g.text.strip()
            weekday = driver.find_elements_by_xpath("//ul[@class='course-info-list mt-20 mt-4 ml-0 pl-0']/li[1]/span[@class='course-info-details text-gray-darkgray']")
            driver.implicitly_wait(3)
#             課程是禮拜幾
            for h in weekday:
                dic['weekday'] = h.text.strip()
            today = datetime.today().strftime("%Y-%m-%d")
        # #           爬蟲時間
            dic["today"] = today
            item_list.append(dic)
    #         time.sleep(3)
    except NameError as e:
        print(str(e))
    finally:
        return item_list
        driver.quit()
def putintoSql(item_list):
#   寫進mysql
    df = pd.DataFrame(item_list)
    engine = create_engine(f'mysql+pymysql://allen:allen0319@192.168.56.150:3306/education?charset=utf8')
    df.to_sql('main',engine,index=False, if_exists = 'replace')

# %%
items = urlandcrawl()
# Out:
# /Users/t3019ein/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
urls_list
# Out:
# ['https://ggc.hkxf.com.tw/course/8UYNA9080/overview',
#  'https://ggc.hkxf.com.tw/course/9P13A9080/overview',
#  'https://ggc.hkxf.com.tw/course/NY11A9080/overview',
#  'https://ggc.hkxf.com.tw/course/8WI9A9080/overview',
#  'https://ggc.hkxf.com.tw/course/9P10A9090/overview',
#  'https://ggc.hkxf.com.tw/course/8UYNA9090/overview',
#  'https://ggc.hkxf.com.tw/course/AH10A9090/overview',
#  'https://ggc.hkxf.com.tw/course/8WB5A9100/overview',
#  'https://ggc.hkxf.com.tw/course/8UYNA9110/overview',
#  'https://ggc.hkxf.com.tw/course/AH15A9110/overview',
#  'https://ggc.hkxf.com.tw/course/9P10A9110/overview',
#  'https://ggc.hkxf.com.tw/course/8W01A9120/overview',
#  'https://ggc.hkxf.com.tw/course/TB01A9120/overview']

# %%
putintoSql(items)

# %%
items
# Out:
# [{'title': '英國巴哈情緒花精&美國NAHA芳療師 聯合說明會 一次學習，全家受惠，終身受用',
#   'during': '2020-08-06 ~ 2020-08-06',
#   'hours': '1.5',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '四 14:00~15:30',
#   'weekday': '2020-08-06 ~ 2020-08-06',
#   'today': '2020-07-30'},
#  {'title': 'CDU系列個案實戰演練課程_台中班 －個案討論會',
#   'during': '2020-08-09 ~ 2020-08-09',
#   'hours': '7',
#   'location': '台中東海大學－臺中市臺灣大道四段1727號管理大樓 東海大學第二教學區',
#   'price': ' 4,000',
#   'time': '09-12；13-17',
#   'weekday': '2020-08-09 ~ 2020-08-09',
#   'today': '2020-07-30'},
#  {'title': '芳療精油洞悉卡諮詢工作坊 引導對話內在能量',
#   'during': '2020-08-09 ~ 2020-08-23',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 9,999',
#   'time': '日10:00~17:00',
#   'weekday': '2020-08-09 ~ 2020-08-23',
#   'today': '2020-07-30'},
#  {'title': '美國會計師證照課程說明會',
#   'during': '2020-08-14 ~ 2020-08-14',
#   'hours': '1',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '19:00~20:00',
#   'weekday': '2020-08-14 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': 'CDU系列聽話、問話、結構化－個案概念化 晤談力初階練功坊',
#   'during': '2020-08-15 ~ 2020-08-15',
#   'hours': '6',
#   'location': '高雄市三民區博愛一路366號14樓',
#   'price': ' 4,000',
#   'time': '09-12；13-16',
#   'weekday': '2020-08-15 ~ 2020-08-15',
#   'today': '2020-07-30'},
#  {'title': '英國巴哈情緒花精 心靈好防疫',
#   'during': '2020-09-05 ~ 2020-09-19',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 5,888',
#   'time': '六10:00~17:00',
#   'weekday': '2020-09-05 ~ 2020-09-19',
#   'today': '2020-07-30'},
#  {'title': '英國巴哈情緒花精&美國NAHA芳療師 聯合說明會 一次學習，全家受惠，終身受用',
#   'during': '2020-09-25 ~ 2020-09-25',
#   'hours': '1.5',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '五 19:00~20:30',
#   'weekday': '2020-09-25 ~ 2020-09-25',
#   'today': '2020-07-30'},
#  {'title': 'CDU系列生命線x生涯卡x能力強項卡_台中班 －輔導工具練功坊一招就上手之簡易晤談工具',
#   'during': '2020-09-27 ~ 2020-09-27',
#   'hours': '6',
#   'location': '台中東海大學－臺中市臺灣大道四段1727號管理大樓 東海大學第二教學區',
#   'price': ' 4,000',
#   'time': '09-12；13-16',
#   'weekday': '2020-09-27 ~ 2020-09-27',
#   'today': '2020-07-30'},
#  {'title': 'CGAP總務採購管理師認證班-台北班',
#   'during': '2020-10-31 ~ 2020-11-28',
#   'hours': '30',
#   'location': '福華會館 公務人力發展中心',
#   'price': ' 11,000',
#   'time': '六 09:30~16:30',
#   'weekday': '2020-10-31 ~ 2020-11-28',
#   'today': '2020-07-30'},
#  {'title': '英國巴哈情緒花精&美國NAHA芳療師 聯合說明會 一次學習，全家受惠，終身受用',
#   'during': '2020-11-06 ~ 2020-11-06',
#   'hours': '1.5',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '五 19:00~20:30',
#   'weekday': '2020-11-06 ~ 2020-11-06',
#   'today': '2020-07-30'},
#  {'title': 'CDU玩樂高思人生－運用樂高六色積木與遊戲箱玩出職涯發展 -台中班',
#   'during': '2020-11-21 ~ 2020-11-21',
#   'hours': '6',
#   'location': '台中東海大學－臺中市臺灣大道四段1727號管理大樓 東海大學第二教學區',
#   'price': ' 7,200',
#   'time': '09-12；13-16',
#   'weekday': '2020-11-21 ~ 2020-11-21',
#   'today': '2020-07-30'},
#  {'title': '英國巴哈情緒花精 解救那些不知所以的情緒輪迴',
#   'during': '2020-11-21 ~ 2020-12-05',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 5,888',
#   'time': '六10:00~17:00',
#   'weekday': '2020-11-21 ~ 2020-12-05',
#   'today': '2020-07-30'},
#  {'title': 'CCE國際證照 GCDF國際認證費 GCDF國際認證費,GCDF',
#   'during': '2020-12-15 ~ 2020-12-31',
#   'hours': '0',
#   'location': '無',
#   'price': ' 5,000',
#   'time': '0000-2400',
#   'weekday': '2020-12-15 ~ 2020-12-31',
#   'today': '2020-07-30'},
#  {'title': '華岡證書線上繳費',
#   'during': '2020-12-31 ~ 2020-12-31',
#   'hours': '0',
#   'location': '',
#   'price': ' 150',
#   'time': '1',
#   'weekday': '2020-12-31 ~ 2020-12-31',
#   'today': '2020-07-30'},
#  {'title': '兒童美術師資認證輔導-台北班 超夯美術老師認證課程，歡迎加入美術老師行列額滿囉!!',
#   'during': '2020-07-26 ~ 2020-09-20',
#   'hours': '48',
#   'location': '福華國際文教會館',
#   'price': ' 15,360',
#   'time': '日 09:00~12:00;日 13:00~16:00',
#   'weekday': '2020-07-26 ~ 2020-09-20',
#   'today': '2020-07-30'},
#  {'title': '兒童全腦開發訓練師認證輔導免費課程體驗及說明會',
#   'during': '2020-07-26 ~ 2020-07-26',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '日 10:00~12:00',
#   'weekday': '2020-07-26 ~ 2020-07-26',
#   'today': '2020-07-30'},
#  {'title': '小小魔術師2020華岡兒童夏令營 魔法的聖物',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '律動功夫營 2020華岡兒童夏令營  兒童防身術',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 1,800',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '小小背包客2020華岡兒童夏令營 小文青相機之旅',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '30',
#   'location': '華岡大安中心',
#   'price': ' 6,200',
#   'time': '一~五 09:00~16:30',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '小小料理達人2020華岡兒童夏令營 法國烘培時光屋',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '兒童珠寶設計師2020華岡兒童夏令營 女孩的手作珠寶(糖果屋裡的鑽石花園)',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 4,000',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '看卡通學漫畫2020華岡兒童夏令營',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '25',
#   'location': '華岡大安中心',
#   'price': ' 6,200',
#   'time': '一~五 09:00~16:00',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '指尖藝術繪粉彩2020華岡兒童夏令營 夏日踏青時光',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '小小哲學家2020華岡兒童夏令營 蘇格拉底的創意啟發-結合手作、桌遊、角色扮演的思辨遊戲',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 5,000',
#   'time': '一~五 09:00~12:00',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '律動英語EH+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 2,100',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '創意Mini車床大師2020華岡兒童夏令營 百變文具機器人',
#   'during': '2020-07-27 ~ 2020-07-31',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,800',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-07-27 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '大自然生態學苑2020華岡兒童夏令營 草山小學堂-小油坑探索路線',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '25',
#   'location': '華岡大安中心',
#   'price': ' 6,500',
#   'time': '一~五 09:00~16:30',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '兒童舞蹈教室 2020華岡兒童夏令營  MV流行街舞TWICE- LIKEY',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 1,800',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '昆蟲星球大發現2020華岡兒童夏令營 夏日蟲蟲培養家',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 4,350',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '呆萌寵物小獸醫2020華岡兒童夏令營 實習小獸醫',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 4,750',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '小小料理達人2020華岡兒童夏令營 西歐下午茶(Low Tea)',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '造型設計師2020華岡兒童夏令營 我的生活日常品(皮件+排鑽+手縫吊飾)',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': 'Coding Maker2020華岡兒童夏令營 創客自造者-智能紅外線/額溫槍',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 5,000',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '活力少年營隊APCS大學程式設計先修培訓 實力養成-基礎班。(第二梯次)',
#   'during': '2020-08-03 ~ 2020-08-14',
#   'hours': '30',
#   'location': '華岡大安中心',
#   'price': ' 10,800',
#   'time': '連續兩週 一~五 09:00~12:00',
#   'weekday': '2020-08-03 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '小小香氛師2020華岡兒童夏令營 彩色香味Life',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 4,000',
#   'time': '一~五 09:00~12:00',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '福爾摩斯解謎遊戲2020華岡兒童夏令營 我會變魔數',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 3,800',
#   'time': '一~五 13:30~16:30',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '壓克力新創畫家2020華岡兒童夏令營 創意技法畫世界',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '全日制 BTS 小小達人夏令營(第二梯)：自造小達人我最棒（確定開班!） 邊玩邊學，快樂學習',
#   'during': '2020-08-03 ~ 2020-08-14',
#   'hours': '80',
#   'location': '大安中心',
#   'price': ' 12,888',
#   'time': '(一)～(五) 08:30-18:00',
#   'weekday': '2020-08-03 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '律動英語 IL+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 2,100',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '多色染創作工作坊2020華岡兒童夏令營 夏日的繽紛染織創作時光',
#   'during': '2020-08-03 ~ 2020-08-07',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-08-03 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '露營小玩家2020華岡兒童夏令營 泰雅獵人彩虹冒險趣',
#   'during': '2020-08-07 ~ 2020-08-09',
#   'hours': '56',
#   'location': '三天兩夜戶外營隊(集合地點:華岡大安中心)',
#   'price': ' 6,750',
#   'time': '五-六-日 09:00~17:00',
#   'weekday': '2020-08-07 ~ 2020-08-09',
#   'today': '2020-07-30'},
#  {'title': '兒童全腦開發訓練師認證輔導初階班 含專注力訓練師資培訓18小時',
#   'during': '2020-08-09 ~ 2020-08-29',
#   'hours': '36',
#   'location': '華岡大安中心',
#   'price': ' 19,800',
#   'time': '六、日 09:00~16:00',
#   'weekday': '2020-08-09 ~ 2020-08-29',
#   'today': '2020-07-30'},
#  {'title': '專注力訓練師資培訓班 有了專注力，學習將事半功倍',
#   'during': '2020-08-09 ~ 2020-08-16',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 9,000',
#   'time': '六、日 09:00~16:00',
#   'weekday': '2020-08-09 ~ 2020-08-16',
#   'today': '2020-07-30'},
#  {'title': '創客異想世界2020華岡兒童夏令營 星際光劍 Maker自造者',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 4,800',
#   'time': '一~五 09:00~12:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': "兒童舞蹈教室 2020華岡兒童夏令營  MV流行街舞BLACKPINK- AS IF IT'S YOUR LAST",
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 1,800',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '開口說話不害怕兒童自信演說表達營 報名課程贈送午餐已額滿',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '25',
#   'location': '華岡大安中心',
#   'price': ' 8,400',
#   'time': '一 ~五 09:20~16:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': 'SCRATCH程式設計兒童夏令營 基礎班 第二期 Fun手玩程式，動畫遊戲設計初體驗',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '30',
#   'location': '華岡大安中心',
#   'price': ' 8,900',
#   'time': '(一)～(五) 09:00-16:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '小小植物觀察家2020華岡兒童夏令營 用五感實踐園藝綠色生活',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '13',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '一~四 09:00~11:30 ；五 09:00~12:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '小小料理達人2020華岡兒童夏令營 皇家點心派對',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '兒童美術大師2020華岡兒童夏令營 拉斐爾500年',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '小紳士小淑女2020華岡兒童夏令營 品格養成x禮儀儀態',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '25',
#   'location': '華岡大安中心',
#   'price': ' 7,000',
#   'time': '一~五 09:00~16:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '德語Ä柏林2020華岡兒童夏令營 "藝"起學德語(旅遊篇)',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': 'micro:bit 2020華岡兒童夏令營  程式營-AI機器偵查戰警',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 5,000',
#   'time': '一~五 13:30~16:30',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '指尖藝術繪粉彩2020華岡兒童夏令營 暑假的希望之光',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '律動英語MQ+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 2,100',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '小小全美語音樂劇表演課-受孩子們喜愛的音樂劇歌曲故事精選 8月Frozen冰雪奇緣班',
#   'during': '2020-08-10 ~ 2020-08-14',
#   'hours': '27.5',
#   'location': 'Y17臺北市青少年發展處 (台北市仁愛路一段17號) 4樓舞蹈教室',
#   'price': ' 16,250',
#   'time': '(一)～(五) 09:00-16:00; 8/14(五) 18:00-19:00演出',
#   'weekday': '2020-08-10 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '小小勇士野外求生營2020華岡兒童夏令營 海賊王野外定向尋寶囉!',
#   'during': '2020-08-16 ~ 2020-08-17',
#   'hours': '33',
#   'location': '兩天一夜戶外營隊(集合地點:華岡大安中心)',
#   'price': ' 4,500',
#   'time': '日~一 09:00~17:30',
#   'weekday': '2020-08-16 ~ 2020-08-17',
#   'today': '2020-07-30'},
#  {'title': '大自然生態學苑2020華岡兒童夏令營 草山小學堂-擎天崗巡禮路線',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '25',
#   'location': '華岡大安中心',
#   'price': ' 6,500',
#   'time': '一~五 09:00~16:30',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '小小魔術師2020華岡兒童夏令營 魔術師的考驗',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '兒童舞蹈教室 2020華岡兒童夏令營  踢踏舞好好玩-Sing Sing Sing 搖擺吧!踢踏舞',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 1,800',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '兒童理財營2020華岡兒童夏令營 富孩子養成計畫',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,800',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '戳戳樂羊毛氈2020華岡兒童夏令營 企鵝烘焙坊',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '烏克麗麗輕鬆彈2020華岡兒童夏令營 彈彈唱唱樂一夏',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '13',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '小小背包客2020華岡兒童夏令營 藝文風卡麥拉旅行',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '30',
#   'location': '華岡大安中心',
#   'price': ' 6,200',
#   'time': '一~五 09:00~16:30',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '小小料理達人2020華岡兒童夏令營 米其林小廚師',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '兒童珠寶設計師2020華岡兒童夏令營 女孩的手作珠寶(人魚公主的星空)',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 4,000',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '經典手工餅乾禮盒製作2020華岡兒童夏令營 洋果子禮盒烘焙營',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '25',
#   'location': '華岡大安中心',
#   'price': ' 6,200',
#   'time': '一~五 09:00~16:00',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '全日制 BTS 小小達人夏令營(第三梯)：探索小達人我最棒（確定開班!） 邊玩邊學，快樂學習',
#   'during': '2020-08-17 ~ 2020-08-28',
#   'hours': '80',
#   'location': '大安中心',
#   'price': ' 12,888',
#   'time': '(一)～(五) 08:30-18:00',
#   'weekday': '2020-08-17 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '律動英語RV+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 2,100',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '創意Mini車床大師2020華岡兒童夏令營 百變文具機器人',
#   'during': '2020-08-17 ~ 2020-08-21',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,800',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-17 ~ 2020-08-21',
#   'today': '2020-07-30'},
#  {'title': '遊戲英語劇團2020英語口語表達與戲劇夏令營 Robin Hood 羅賓漢',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '25',
#   'location': '台北市中山區長安東路二段92號2樓',
#   'price': ' 15,000',
#   'time': '一~五 09:30~17:00',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '手繪時尚服裝畫2020華岡兒童夏令營 Kids Fashion Drawing-2020流行最經典篇',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,800',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '兒童舞蹈教室 2020華岡兒童夏令營  MV流行街舞GFRIEND-Me gustas tu',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 1,800',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '曠世奇才科學家2020華岡兒童夏令營 食尚玩家科學營',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 4,000',
#   'time': '一~五 09:00~12:00',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '輕水彩繪畫日記2020華岡兒童夏令營 快樂的生活點滴',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '小小料理達人2020華岡兒童夏令營 義式主廚私房菜',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '兒童美術大師2020華岡兒童夏令營 素描就是這麼好玩',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '魔法麥克風2019華岡兒童夏令營 小小主持人口才養成遊戲營',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,800',
#   'time': '一~五 09:00~11:30',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '手作烘培1號店2020華岡兒童夏令營 手感溫度vs滋味好禮',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '25',
#   'location': '華岡大安中心',
#   'price': ' 6,200',
#   'time': '一~五 09:00~16:00',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '小時光手工皂2020華岡兒童夏令營 天然手工皂高階小達人',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '12.5',
#   'location': '華岡大安中心',
#   'price': ' 3,800',
#   'time': '一~五 13:30~16:00',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '律動英語WZ+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#   'during': '2020-08-24 ~ 2020-08-28',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 2,100',
#   'time': '一~五 16:30~18:00',
#   'weekday': '2020-08-24 ~ 2020-08-28',
#   'today': '2020-07-30'},
#  {'title': '兒童全腦開發訓練師認證輔導進階班',
#   'during': '2020-08-30 ~ 2020-09-19',
#   'hours': '36',
#   'location': '華岡大安中心',
#   'price': ' 19,800',
#   'time': '六、日 09:00~16:00',
#   'weekday': '2020-08-30 ~ 2020-09-19',
#   'today': '2020-07-30'},
#  {'title': '國小數學中年級師資培訓班 資深國小數學老師，帶你輕鬆教數學',
#   'during': '2020-09-06 ~ 2020-09-27',
#   'hours': '12',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '日 09:00~12:00',
#   'weekday': '2020-09-06 ~ 2020-09-27',
#   'today': '2020-07-30'},
#  {'title': '國語正音教學師資培訓 業界最完整正音教學全修課程讓你現學現用沒煩惱',
#   'during': '2020-09-06 ~ 2020-09-20',
#   'hours': '18',
#   'location': '福華文教會館',
#   'price': ' 6,000',
#   'time': '日 09:30~16:30',
#   'weekday': '2020-09-06 ~ 2020-09-20',
#   'today': '2020-07-30'},
#  {'title': 'SCRATCH程式設計師資培訓班免費說明會 掌握程式語言掌握未來趨勢！',
#   'during': '2020-09-10 ~ 2020-09-10',
#   'hours': '1.5',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '(四)19:00~20:30',
#   'weekday': '2020-09-10 ~ 2020-09-10',
#   'today': '2020-07-30'},
#  {'title': 'SCRATCH程式設計師資培訓班免費說明會 掌握程式語言掌握未來趨勢！',
#   'during': '2020-09-12 ~ 2020-09-12',
#   'hours': '1.5',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '(六)14:00~15:30',
#   'weekday': '2020-09-12 ~ 2020-09-12',
#   'today': '2020-07-30'},
#  {'title': '兒童全腦開發訓練師認證輔導免費課程體驗及說明會',
#   'during': '2020-09-15 ~ 2020-09-15',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '二 10:00~12:00',
#   'weekday': '2020-09-15 ~ 2020-09-15',
#   'today': '2020-07-30'},
#  {'title': '兒童課後照顧服務人員職前訓練課程 符合資格，結訓當日立即領取新北市政府教育局證書今年最後一梯次唷!!',
#   'during': '2020-09-19 ~ 2021-01-30',
#   'hours': '180',
#   'location': '福華國際文教會館',
#   'price': ' 15,000',
#   'time': '六~日 09:00~16:00',
#   'weekday': '2020-09-19 ~ 2021-01-30',
#   'today': '2020-07-30'},
#  {'title': '多元智能檢測分析師認證輔導免費課程說明會 在不景氣中開創大好商機!!',
#   'during': '2020-09-24 ~ 2020-09-24',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '四 19:00~21:00',
#   'weekday': '2020-09-24 ~ 2020-09-24',
#   'today': '2020-07-30'},
#  {'title': '兒童全腦開發訓練師認證輔導初階班 含專注力訓練師資培訓18小時',
#   'during': '2020-09-29 ~ 2020-11-17',
#   'hours': '36',
#   'location': '華岡大安中心',
#   'price': ' 19,800',
#   'time': '二 09:00~14:30',
#   'weekday': '2020-09-29 ~ 2020-11-17',
#   'today': '2020-07-30'},
#  {'title': '專注力訓練師資培訓班 有了專注力，學習將事半功倍',
#   'during': '2020-09-29 ~ 2020-10-20',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 9,000',
#   'time': '二 09:00~14:30',
#   'weekday': '2020-09-29 ~ 2020-10-20',
#   'today': '2020-07-30'},
#  {'title': 'SCRATCH程式設計師資培訓班 平日晚間班',
#   'during': '2020-10-05 ~ 2020-10-21',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 9,000',
#   'time': '(一)、(三) 19:00~22:00',
#   'weekday': '2020-10-05 ~ 2020-10-21',
#   'today': '2020-07-30'},
#  {'title': '感覺統合運動遊戲人員培訓班理論實務兼具 (原"感覺統合教學師資培訓班")',
#   'during': '2020-10-07 ~ 2020-12-09',
#   'hours': '25',
#   'location': '福華國際文教會館',
#   'price': ' 8,400',
#   'time': '三 19:00~21:30',
#   'weekday': '2020-10-07 ~ 2020-12-09',
#   'today': '2020-07-30'},
#  {'title': 'SCRATCH程式設計師資培訓班 假日白天班',
#   'during': '2020-10-11 ~ 2020-10-25',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 9,000',
#   'time': '(日)09:00~16:00',
#   'weekday': '2020-10-11 ~ 2020-10-25',
#   'today': '2020-07-30'},
#  {'title': '多元智能檢測分析師認證輔導 ～在不景氣中開創大好商機!!',
#   'during': '2020-10-15 ~ 2020-12-03',
#   'hours': '24',
#   'location': '華岡大安中心',
#   'price': ' 13,200',
#   'time': '四 18:30~21:30',
#   'weekday': '2020-10-15 ~ 2020-12-03',
#   'today': '2020-07-30'},
#  {'title': '兒童全腦開發訓練師認證輔導兒童發展理論與實務 含班級經營與親師溝通',
#   'during': '2020-10-17 ~ 2020-10-25',
#   'hours': '24',
#   'location': '華岡大安中心',
#   'price': ' 13,200',
#   'time': '六、日 09:00~16:00',
#   'weekday': '2020-10-17 ~ 2020-10-25',
#   'today': '2020-07-30'},
#  {'title': 'TAYL兒童美術師資認證輔導-台中班 超夯美術老師認證課程，歡迎加入美術老師行列',
#   'during': '2020-10-18 ~ 2020-11-22',
#   'hours': '48',
#   'location': '台中東海大學－臺中市臺灣大道四段1727號管理大樓 東海大學第二教學區',
#   'price': ' 16,000',
#   'time': '日 09:00~13:00;日 14:00~18:00',
#   'weekday': '2020-10-18 ~ 2020-11-22',
#   'today': '2020-07-30'},
#  {'title': '英語繪本師資培訓班 超強兒童繪本講師親自授課',
#   'during': '2020-10-18 ~ 2020-11-08',
#   'hours': '24',
#   'location': '華岡大安中心',
#   'price': ' 6,200',
#   'time': '日 09:30~16:30',
#   'weekday': '2020-10-18 ~ 2020-11-08',
#   'today': '2020-07-30'},
#  {'title': '閩南語語言能力認證考試輔導班 歡迎聽懂台語、對台語推廣有興趣、不限國籍年齡報名參加',
#   'during': '2020-10-24 ~ 2021-01-30',
#   'hours': '36',
#   'location': '福華國際文教會館',
#   'price': ' 7,000',
#   'time': '六 09:00~12:00',
#   'weekday': '2020-10-24 ~ 2021-01-30',
#   'today': '2020-07-30'},
#  {'title': '國小數學高年級師資培訓班',
#   'during': '2020-10-25 ~ 2020-11-29',
#   'hours': '18',
#   'location': '華岡大安中心或福華國際文教會館',
#   'price': ' 5,400',
#   'time': '日 09:00~12:00',
#   'weekday': '2020-10-25 ~ 2020-11-29',
#   'today': '2020-07-30'},
#  {'title': 'CWT兒童作文師資認證輔導',
#   'during': '2020-10-25 ~ 2020-12-06',
#   'hours': '42',
#   'location': '公務人力發展中心 福華會館',
#   'price': ' 12,000',
#   'time': '日 09:00~16:00',
#   'weekday': '2020-10-25 ~ 2020-12-06',
#   'today': '2020-07-30'},
#  {'title': '手工皂專業師資認證研習營 教學創業無往不利',
#   'during': '2020-11-08 ~ 2021-01-31',
#   'hours': '78',
#   'location': '福華國際會館',
#   'price': ' 39,000',
#   'time': '日10:00~17:00',
#   'weekday': '2020-11-08 ~ 2021-01-31',
#   'today': '2020-07-30'},
#  {'title': '兒童全腦開發訓練師認證輔導進階班',
#   'during': '2020-11-24 ~ 2021-01-12',
#   'hours': '36',
#   'location': '華岡大安中心',
#   'price': ' 19,800',
#   'time': '二 09:00~14:30',
#   'weekday': '2020-11-24 ~ 2021-01-12',
#   'today': '2020-07-30'},
#  {'title': '兒童全腦開發訓練師認證輔導兒童發展理論與實務 含班級經營與親師溝通',
#   'during': '2021-01-19 ~ 2021-02-09',
#   'hours': '24',
#   'location': '華岡大安中心',
#   'price': ' 13,200',
#   'time': '二 09:00~14:00',
#   'weekday': '2021-01-19 ~ 2021-02-09',
#   'today': '2020-07-30'},
#  {'title': '閩南語語言能力認證考試加強班 針對想考B2級閩南語語言能力做加強培訓喔!!',
#   'during': '2021-03-06 ~ 2021-06-19',
#   'hours': '36',
#   'location': '福華國際文教會館',
#   'price': ' 7,000',
#   'time': '六 09:00~12:00',
#   'weekday': '2021-03-06 ~ 2021-06-19',
#   'today': '2020-07-30'},
#  {'title': '劍橋兒童英語家教班免費試上與說明會 比請家教更好的品質！比上補習班更漂亮的價格！',
#   'during': '2021-12-31 ~ 2021-12-31',
#   'hours': '2.5',
#   'location': '大安中心',
#   'price': ' 0',
#   'time': '10:00~12:30',
#   'weekday': '2021-12-31 ~ 2021-12-31',
#   'today': '2020-07-30'},
#  {'title': '藥草女巫手作-金錢魔法薰香粉 學費含材料費',
#   'during': '2020-07-26 ~ 2020-07-26',
#   'hours': '2',
#   'location': '大安中心',
#   'price': ' 3,500',
#   'time': '日10:00~12:00',
#   'weekday': '2020-07-26 ~ 2020-07-26',
#   'today': '2020-07-30'},
#  {'title': '液體皂時光 潔身抗菌系列',
#   'during': '2020-07-28 ~ 2020-08-11',
#   'hours': '9',
#   'location': '華岡大安中心',
#   'price': ' 2,400',
#   'time': '二 18:50~21:50',
#   'weekday': '2020-07-28 ~ 2020-08-11',
#   'today': '2020-07-30'},
#  {'title': 'Pure soap手工皂快樂學',
#   'during': '2020-07-30 ~ 2020-09-03',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 3,200',
#   'time': '四19:00-21:30',
#   'weekday': '2020-07-30 ~ 2020-09-03',
#   'today': '2020-07-30'},
#  {'title': '小小銀匠體驗 GIFTIE新金工銀黏土飾品教學',
#   'during': '2020-07-31 ~ 2020-07-31',
#   'hours': '2.5',
#   'location': '台北市南京東路四段2號1-10號店鋪(台北小巨蛋內)',
#   'price': ' 3,880',
#   'time': '11:00~13:30或14:00~16:30或16:30~19:00（7/1～7/31區間日期可選擇)',
#   'weekday': '2020-07-31 ~ 2020-07-31',
#   'today': '2020-07-30'},
#  {'title': '壓克力同樂繪主題3 [晚上班] <再1位就開班> 全新單元 歡迎舊生續報，也很歡迎新生喔，零基礎可！',
#   'during': '2020-08-05 ~ 2020-09-23',
#   'hours': '16',
#   'location': '華岡大安中心',
#   'price': ' 4,400',
#   'time': '(三)19:00~21:00',
#   'weekday': '2020-08-05 ~ 2020-09-23',
#   'today': '2020-07-30'},
#  {'title': '露比的點心茶會｜仿真甜點飾品手作',
#   'during': '2020-08-05 ~ 2020-08-19',
#   'hours': '7.5',
#   'location': '華岡大安中心',
#   'price': ' 3,200',
#   'time': '(三)19:00~21:30',
#   'weekday': '2020-08-05 ~ 2020-08-19',
#   'today': '2020-07-30'},
#  {'title': '水性色鉛筆彩繪｜風景小藝思',
#   'during': '2020-08-06 ~ 2020-09-10',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 3,900',
#   'time': '(四)19:00~21:30',
#   'weekday': '2020-08-06 ~ 2020-09-10',
#   'today': '2020-07-30'},
#  {'title': '藥草女巫手作-淨化保護魔法噴霧 學費含材料費',
#   'during': '2020-08-07 ~ 2020-08-07',
#   'hours': '2',
#   'location': '大安中心',
#   'price': ' 3,500',
#   'time': '五19:00~21:00',
#   'weekday': '2020-08-07 ~ 2020-08-07',
#   'today': '2020-07-30'},
#  {'title': '布克生活插畫課明信片小旅行-田園北海道 [週二下午班] 再1位就開班！',
#   'during': '2020-08-11 ~ 2020-09-15',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 4,950',
#   'time': '(二)14:00~17:00',
#   'weekday': '2020-08-11 ~ 2020-09-15',
#   'today': '2020-07-30'},
#  {'title': '居家整理收納術確定開班 整理心 整理家 充滿愛',
#   'during': '2020-08-15 ~ 2020-08-29',
#   'hours': '9',
#   'location': '公務人力發展中心-福華國際文教會館',
#   'price': ' 6,800',
#   'time': '六，09:30-12:30',
#   'weekday': '2020-08-15 ~ 2020-08-29',
#   'today': '2020-07-30'},
#  {'title': '占星不求人初階占星學 從零開始學占星',
#   'during': '2020-08-18 ~ 2020-09-29',
#   'hours': '17.5',
#   'location': '福華國際文教會館',
#   'price': ' 6,300',
#   'time': '二 19:00~21:30',
#   'weekday': '2020-08-18 ~ 2020-09-29',
#   'today': '2020-07-30'},
#  {'title': '生活速寫轉角咖啡廳．城市巷弄．自己的房間',
#   'during': '2020-08-20 ~ 2020-10-15',
#   'hours': '16',
#   'location': '華岡大安中心',
#   'price': ' 4,400',
#   'time': '(四)19:00~21:00',
#   'weekday': '2020-08-20 ~ 2020-10-15',
#   'today': '2020-07-30'},
#  {'title': '藥草女巫手作-愛情魔法油 學費含材料費',
#   'during': '2020-08-20 ~ 2020-08-20',
#   'hours': '2',
#   'location': '大安中心',
#   'price': ' 3,500',
#   'time': '四 10:00~12:00',
#   'weekday': '2020-08-20 ~ 2020-08-20',
#   'today': '2020-07-30'},
#  {'title': '七夕催桃花密技：就要以貌取人！懂手面相才能找好對象 加映生肖&風水增進桃花、抓住幸福',
#   'during': '2020-08-20 ~ 2020-08-20',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 1,000',
#   'time': '週四19:00~21:00',
#   'weekday': '2020-08-20 ~ 2020-08-20',
#   'today': '2020-07-30'},
#  {'title': '夏日清涼飲品蠟燭 全新企劃',
#   'during': '2020-08-21 ~ 2020-09-04',
#   'hours': '9',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '五 18:50-21:50',
#   'weekday': '2020-08-21 ~ 2020-09-04',
#   'today': '2020-07-30'},
#  {'title': '紫微斗數初階入門(周日上午班) 輕鬆學會解讀命盤=主宰你的人生',
#   'during': '2020-08-23 ~ 2020-11-08',
#   'hours': '20',
#   'location': '華岡大安中心',
#   'price': ' 8,000',
#   'time': '週日10:00~12:00',
#   'weekday': '2020-08-23 ~ 2020-11-08',
#   'today': '2020-07-30'},
#  {'title': '浪漫風情小夜燈 NEW蠟材創作',
#   'during': '2020-08-26 ~ 2020-08-26',
#   'hours': '2.5',
#   'location': '華岡大安中心',
#   'price': ' 1,300',
#   'time': '三19:00-21:30',
#   'weekday': '2020-08-26 ~ 2020-08-26',
#   'today': '2020-07-30'},
#  {'title': '免澆水仙人掌創意蠟燭 NEW 辦公室療癒蠟燭',
#   'during': '2020-08-27 ~ 2020-08-27',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 800',
#   'time': '四19:00~21:00',
#   'weekday': '2020-08-27 ~ 2020-08-27',
#   'today': '2020-07-30'},
#  {'title': '自製金箔透明溫感「花」心思變色唇膏 周末療癒夜',
#   'during': '2020-08-29 ~ 2020-08-29',
#   'hours': '3.5',
#   'location': '華岡大安中心',
#   'price': ' 1,800',
#   'time': '六17:00-20:30',
#   'weekday': '2020-08-29 ~ 2020-08-29',
#   'today': '2020-07-30'},
#  {'title': '文青銀匠體驗 GIFTIE新金工銀黏土飾品教學',
#   'during': '2020-08-31 ~ 2020-08-31',
#   'hours': '2.5',
#   'location': '台北市南京東路四段2號1-10號店鋪(台北小巨蛋內)',
#   'price': ' 3,880',
#   'time': '11:00~13:30或14:00~16:30或16:30~19:00(7/1-7/31區間日期可選擇)',
#   'weekday': '2020-08-31 ~ 2020-08-31',
#   'today': '2020-07-30'},
#  {'title': '繽紛果醬蠟燭 好評加開',
#   'during': '2020-08-31 ~ 2020-08-31',
#   'hours': '3',
#   'location': '華岡大安中心',
#   'price': ' 1,200',
#   'time': '一 18:50~21:50',
#   'weekday': '2020-08-31 ~ 2020-08-31',
#   'today': '2020-07-30'},
#  {'title': '書法研習班 免費講座',
#   'during': '2020-09-01 ~ 2020-09-01',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '二14:00~16:00',
#   'weekday': '2020-09-01 ~ 2020-09-01',
#   'today': '2020-07-30'},
#  {'title': '書法研習班 免費講座',
#   'during': '2020-09-01 ~ 2020-09-01',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '二18:30~20:00',
#   'weekday': '2020-09-01 ~ 2020-09-01',
#   'today': '2020-07-30'},
#  {'title': '日本和諧粉彩準指導師培訓 平日班',
#   'during': '2020-09-01 ~ 2020-09-15',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 18,800',
#   'time': '二 09:30~16:30',
#   'weekday': '2020-09-01 ~ 2020-09-15',
#   'today': '2020-07-30'},
#  {'title': '布克生活插畫課明信片小旅行-田園北海道 [週二晚上班]',
#   'during': '2020-09-01 ~ 2020-10-20',
#   'hours': '16',
#   'location': '華岡大安中心',
#   'price': ' 4,400',
#   'time': '(二)19:00~21:00',
#   'weekday': '2020-09-01 ~ 2020-10-20',
#   'today': '2020-07-30'},
#  {'title': '輕鬆學繪．輕水彩 小花先生',
#   'during': '2020-09-01 ~ 2020-10-06',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 3,900',
#   'time': '(二)19:00~21:30',
#   'weekday': '2020-09-01 ~ 2020-10-06',
#   'today': '2020-07-30'},
#  {'title': '紫微斗數初階入門(平日晚上班) 輕鬆學會解讀命盤=主宰你的人生',
#   'during': '2020-09-01 ~ 2020-11-03',
#   'hours': '20',
#   'location': '華岡大安中心',
#   'price': ' 8,000',
#   'time': '週二19:00~21:00',
#   'weekday': '2020-09-01 ~ 2020-11-03',
#   'today': '2020-07-30'},
#  {'title': '一次學會易經占卜 透視人生的智慧寶典，現在報名還有好禮相送！',
#   'during': '2020-09-01 ~ 2020-10-06',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 9,000',
#   'time': '週二19:00~21:00',
#   'weekday': '2020-09-01 ~ 2020-10-06',
#   'today': '2020-07-30'},
#  {'title': '大天使神諭占卡 簡單上手的占卜工具，結合啟發及靜⼼',
#   'during': '2020-09-03 ~ 2020-10-15',
#   'hours': '12',
#   'location': '福華會館公務人力發展中心',
#   'price': ' 3,600',
#   'time': '四19:00-21:00',
#   'weekday': '2020-09-03 ~ 2020-10-15',
#   'today': '2020-07-30'},
#  {'title': '兒童收納引導術',
#   'during': '2020-09-05 ~ 2020-09-05',
#   'hours': '3',
#   'location': '華岡大安中心',
#   'price': ' 1,800',
#   'time': '六，09:30-12:30',
#   'weekday': '2020-09-05 ~ 2020-09-05',
#   'today': '2020-07-30'},
#  {'title': 'UV樹脂設計-金屬框造型 (基礎班) 週六下午',
#   'during': '2020-09-05 ~ 2020-09-05',
#   'hours': '2.5',
#   'location': '華岡大安中心',
#   'price': ' 850',
#   'time': '(六)13:30~16:00',
#   'weekday': '2020-09-05 ~ 2020-09-05',
#   'today': '2020-07-30'},
#  {'title': '書法研習班',
#   'during': '2020-09-08 ~ 2020-11-03',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '二14:00~16:00',
#   'weekday': '2020-09-08 ~ 2020-11-03',
#   'today': '2020-07-30'},
#  {'title': '書法研習班',
#   'during': '2020-09-08 ~ 2020-11-03',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '二18:30~20:30',
#   'weekday': '2020-09-08 ~ 2020-11-03',
#   'today': '2020-07-30'},
#  {'title': '就愛玩混搭─彩墨與色鉛的雙重奏',
#   'during': '2020-09-08 ~ 2020-10-27',
#   'hours': '20',
#   'location': '華岡大安中心',
#   'price': ' 6,000',
#   'time': '(二)19:00~21:00',
#   'weekday': '2020-09-08 ~ 2020-10-27',
#   'today': '2020-07-30'},
#  {'title': 'Pure soap寶石皂創意 浪漫時光',
#   'during': '2020-09-08 ~ 2020-09-08',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 2,400',
#   'time': '二10:00-17:00',
#   'weekday': '2020-09-08 ~ 2020-09-08',
#   'today': '2020-07-30'},
#  {'title': '渲染‧玩皂B班 午後時光',
#   'during': '2020-09-10 ~ 2020-09-24',
#   'hours': '12',
#   'location': '華岡大安中心',
#   'price': ' 4,200',
#   'time': '四14:00-18:00',
#   'weekday': '2020-09-10 ~ 2020-09-24',
#   'today': '2020-07-30'},
#  {'title': '手沖咖啡入門',
#   'during': '2020-09-11 ~ 2020-09-11',
#   'hours': '3',
#   'location': '華岡大安中心',
#   'price': ' 1,350',
#   'time': '週五 13:30-16:30',
#   'weekday': '2020-09-11 ~ 2020-09-11',
#   'today': '2020-07-30'},
#  {'title': '凡爾賽玫瑰蛋糕皂 NEW 韓式擠花技巧大進擊',
#   'during': '2020-09-12 ~ 2020-09-12',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 2,500',
#   'time': '六13:30-20:30',
#   'weekday': '2020-09-12 ~ 2020-09-12',
#   'today': '2020-07-30'},
#  {'title': 'UV樹脂設計-水晶花球耳環 (中階班) 週三晚上',
#   'during': '2020-09-12 ~ 2020-09-12',
#   'hours': '2.5',
#   'location': '華岡大安中心',
#   'price': ' 1,050',
#   'time': '(六)13:30~16:00',
#   'weekday': '2020-09-12 ~ 2020-09-12',
#   'today': '2020-07-30'},
#  {'title': '水性色鉛筆彩繪｜美食小藝思 （第4期）新菜單！',
#   'during': '2020-09-15 ~ 2020-10-20',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 3,900',
#   'time': '(二)14:00~16:30',
#   'weekday': '2020-09-15 ~ 2020-10-20',
#   'today': '2020-07-30'},
#  {'title': '當代金工創作–用故事來製作物件 [上午班] mental work with in metal work',
#   'during': '2020-09-15 ~ 2020-11-03',
#   'hours': '32',
#   'location': '華岡大安中心',
#   'price': ' 12,800',
#   'time': '(二)09:00~13:00',
#   'weekday': '2020-09-15 ~ 2020-11-03',
#   'today': '2020-07-30'},
#  {'title': '速繪我的旅遊時代漫遊歐洲 輕柔剔透的輕水彩技法，方便攜帶及且能快速完成 >>再2位就開班',
#   'during': '2020-09-16 ~ 2020-11-04',
#   'hours': '16',
#   'location': '華岡大安中心',
#   'price': ' 4,400',
#   'time': '(三)19:00~21:00',
#   'weekday': '2020-09-16 ~ 2020-11-04',
#   'today': '2020-07-30'},
#  {'title': '寵愛肌膚保養品DIY NEW',
#   'during': '2020-09-16 ~ 2020-09-30',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 2,500',
#   'time': '三19:00~21:00',
#   'weekday': '2020-09-16 ~ 2020-09-30',
#   'today': '2020-07-30'},
#  {'title': '當油性色鉛筆遇上牛皮紙｜凜小花的美味Look 第3期',
#   'during': '2020-09-17 ~ 2020-11-05',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 3,900',
#   'time': '(四)19:00~21:30',
#   'weekday': '2020-09-17 ~ 2020-11-05',
#   'today': '2020-07-30'},
#  {'title': 'Pure soap手工皂快樂學',
#   'during': '2020-09-17 ~ 2020-10-29',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 3,200',
#   'time': '四19:00~21:30',
#   'weekday': '2020-09-17 ~ 2020-10-29',
#   'today': '2020-07-30'},
#  {'title': '手沖咖啡入門',
#   'during': '2020-09-19 ~ 2020-09-19',
#   'hours': '3',
#   'location': '華岡大安中心',
#   'price': ' 1,350',
#   'time': '週六 13:00-16:00',
#   'weekday': '2020-09-19 ~ 2020-09-19',
#   'today': '2020-07-30'},
#  {'title': '超寫實袖珍食玩月圓之夜伴手禮',
#   'during': '2020-09-20 ~ 2020-09-20',
#   'hours': '4',
#   'location': '華岡大安中心',
#   'price': ' 1,700',
#   'time': '日 13:00~17:00',
#   'weekday': '2020-09-20 ~ 2020-09-20',
#   'today': '2020-07-30'},
#  {'title': '咖啡感官訓練入門',
#   'during': '2020-09-25 ~ 2020-09-25',
#   'hours': '3',
#   'location': '華岡大安中心',
#   'price': ' 1,350',
#   'time': '週五 13:30-16:30',
#   'weekday': '2020-09-25 ~ 2020-09-25',
#   'today': '2020-07-30'},
#  {'title': '漫畫創作職涯多元發展 結合職場與商業',
#   'during': '2020-09-25 ~ 2020-09-25',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 3,000',
#   'time': '五14:00~21:00',
#   'weekday': '2020-09-25 ~ 2020-09-25',
#   'today': '2020-07-30'},
#  {'title': '圓圈繪畫基礎導師認證課程 ☞ 9/13前報名享早鳥價省$1,500元！',
#   'during': '2020-09-27 ~ 2020-09-27',
#   'hours': '6',
#   'location': '台北市大安區',
#   'price': ' 8,000',
#   'time': '(日)10:00~17:00',
#   'weekday': '2020-09-27 ~ 2020-09-27',
#   'today': '2020-07-30'},
#  {'title': 'Pure soap手工皂快樂學 午后時光',
#   'during': '2020-10-13 ~ 2020-11-17',
#   'hours': '15',
#   'location': '華岡大安中心',
#   'price': ' 3,200',
#   'time': '二14:00~16:30',
#   'weekday': '2020-10-13 ~ 2020-11-17',
#   'today': '2020-07-30'},
#  {'title': '占星不求人進階占星學',
#   'during': '2020-10-13 ~ 2020-11-24',
#   'hours': '17.5',
#   'location': '福華國際文教會館',
#   'price': ' 6,500',
#   'time': '二 19:00~21:30',
#   'weekday': '2020-10-13 ~ 2020-11-24',
#   'today': '2020-07-30'},
#  {'title': '雷諾曼牌卡占卜初階班 歐洲百年皇家御用的占卜法今年唯一一梯，欲報從速',
#   'during': '2020-10-15 ~ 2020-11-12',
#   'hours': '12.5',
#   'location': '福華國際文教會館',
#   'price': ' 8,600',
#   'time': '四 19:00~21:30',
#   'weekday': '2020-10-15 ~ 2020-11-12',
#   'today': '2020-07-30'},
#  {'title': '輕鬆學會塔羅牌塔羅牌78張新星班 奠定塔羅奧義基礎，開啟心靈覺察力',
#   'during': '2020-10-16 ~ 2020-11-20',
#   'hours': '15',
#   'location': '福華國際文教會館',
#   'price': ' 5,250',
#   'time': '五 19:00~21:30',
#   'weekday': '2020-10-16 ~ 2020-11-20',
#   'today': '2020-07-30'},
#  {'title': 'Pure soap寶石皂創意 周末時光',
#   'during': '2020-10-17 ~ 2020-10-17',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 2,400',
#   'time': '六14:00~21:00',
#   'weekday': '2020-10-17 ~ 2020-10-17',
#   'today': '2020-07-30'},
#  {'title': '仿真場景模型製作｜台灣街角情境',
#   'during': '2020-10-18 ~ 2020-11-01',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 6,800',
#   'time': '(日)09:30~16:30',
#   'weekday': '2020-10-18 ~ 2020-11-01',
#   'today': '2020-07-30'},
#  {'title': '漫畫創作職涯多元發展 結合職場與商業',
#   'during': '2020-10-24 ~ 2020-10-24',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 3,000',
#   'time': '六14:00~21:00',
#   'weekday': '2020-10-24 ~ 2020-10-24',
#   'today': '2020-07-30'},
#  {'title': 'Just for U 百變*皂*型 幸福感包裝 百變*皂*型',
#   'during': '2020-10-31 ~ 2020-10-31',
#   'hours': '4',
#   'location': '華岡大安中心',
#   'price': ' 1,000',
#   'time': '六 17:30~21:30',
#   'weekday': '2020-10-31 ~ 2020-10-31',
#   'today': '2020-07-30'},
#  {'title': '整理收納諮詢師認證 全台首張職能導向認證',
#   'during': '2020-11-07 ~ 2020-12-05',
#   'hours': '21',
#   'location': '華岡大安中心',
#   'price': ' 18,000',
#   'time': '六，09:30-16:30',
#   'weekday': '2020-11-07 ~ 2020-12-05',
#   'today': '2020-07-30'},
#  {'title': '超寫實袖珍食玩眷村的家鄉味 乾麵or雞肉飯套餐，你今天想吃哪一道?',
#   'during': '2020-11-15 ~ 2020-11-22',
#   'hours': '7',
#   'location': '華岡大安中心',
#   'price': ' 3,000',
#   'time': '日 13:30-17:00',
#   'weekday': '2020-11-15 ~ 2020-11-22',
#   'today': '2020-07-30'},
#  {'title': '雷諾曼牌卡占卜進階班 歐洲百年皇家御用的占卜法進階班',
#   'during': '2020-11-19 ~ 2020-12-17',
#   'hours': '12.5',
#   'location': '福華國際文教會館',
#   'price': ' 8,600',
#   'time': '四 19:00~21:30',
#   'weekday': '2020-11-19 ~ 2020-12-17',
#   'today': '2020-07-30'},
#  {'title': '塔羅牌進階實戰班 牌陣實例導引，養成實際解牌能力',
#   'during': '2020-11-27 ~ 2021-01-08',
#   'hours': '15',
#   'location': '福華國際文教會館',
#   'price': ' 6,000',
#   'time': '五 19:00~21:30',
#   'weekday': '2020-11-27 ~ 2021-01-08',
#   'today': '2020-07-30'},
#  {'title': '超寫實袖珍食玩溫暖宅味夾心吐司',
#   'during': '2020-12-20 ~ 2020-12-20',
#   'hours': '4',
#   'location': '華岡大安中心',
#   'price': ' 1,700',
#   'time': '(日) 13:00~17:00',
#   'weekday': '2020-12-20 ~ 2020-12-20',
#   'today': '2020-07-30'},
#  {'title': '圓圈繪畫基礎導師認證課程 已額滿，可來電預約下梯次 ☞ 7/11前報名享早鳥價省$1,500元！',
#   'during': '2020-07-25 ~ 2020-07-25',
#   'hours': '6',
#   'location': '身障資源中心─五樓體適能室',
#   'price': ' 8,000',
#   'time': '(六)10:00~17:00',
#   'weekday': '2020-07-25 ~ 2020-07-25',
#   'today': '2020-07-30'},
#  {'title': '芳療聊心話-色彩與脈輪 精油五感很靜心',
#   'during': '2020-07-26 ~ 2020-07-26',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 1,800',
#   'time': '日 09:30~16:30',
#   'weekday': '2020-07-26 ~ 2020-07-26',
#   'today': '2020-07-30'},
#  {'title': 'NAHA美國整體芳療師認證-高階I學科 成為專業芳療師',
#   'during': '2020-08-01 ~ 2020-12-05',
#   'hours': '83',
#   'location': '大安中心',
#   'price': ' 25,000',
#   'time': '六10:00~17:00',
#   'weekday': '2020-08-01 ~ 2020-12-05',
#   'today': '2020-07-30'},
#  {'title': 'HOME SPA香氛養生之道 身心合一，動靜結合',
#   'during': '2020-08-02 ~ 2020-08-23',
#   'hours': '12',
#   'location': '華岡大安中心',
#   'price': ' 4,200',
#   'time': '日 09:30~12:30',
#   'weekday': '2020-08-02 ~ 2020-08-23',
#   'today': '2020-07-30'},
#  {'title': '本草王的膝關節名方論 教你如何改善膝關節退化等問題',
#   'during': '2020-08-03 ~ 2020-10-19',
#   'hours': '30',
#   'location': '華岡大安中心',
#   'price': ' 7,800',
#   'time': '(一) 19:00-21:30',
#   'weekday': '2020-08-03 ~ 2020-10-19',
#   'today': '2020-07-30'},
#  {'title': '免費課程說明會-銀髮族藝術陪伴與自我照顧 失落情緒議題 & 樂齡藝術陪伴師資認證',
#   'during': '2020-08-09 ~ 2020-08-09',
#   'hours': '1.5',
#   'location': '福華國際文教會館',
#   'price': ' 0',
#   'time': '日 10:00~11:30',
#   'weekday': '2020-08-09 ~ 2020-08-09',
#   'today': '2020-07-30'},
#  {'title': 'NAHA美國整體芳療師認證-初階II 專業芳療進階',
#   'during': '2020-08-15 ~ 2020-09-19',
#   'hours': '32',
#   'location': '華岡大安中心',
#   'price': ' 9,000',
#   'time': '六10:00~17:00',
#   'weekday': '2020-08-15 ~ 2020-09-19',
#   'today': '2020-07-30'},
#  {'title': '母嬰照護認證聯合說明會',
#   'during': '2020-08-18 ~ 2020-08-18',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '二 10:00~12:00',
#   'weekday': '2020-08-18 ~ 2020-08-18',
#   'today': '2020-07-30'},
#  {'title': 'NAHA美國整體芳療師認證-初階I 踏入專業芳療的第一步,小班制',
#   'during': '2020-08-23 ~ 2020-09-27',
#   'hours': '32',
#   'location': '華岡大安中心',
#   'price': ' 8,500',
#   'time': '日10:00~17:00',
#   'weekday': '2020-08-23 ~ 2020-09-27',
#   'today': '2020-07-30'},
#  {'title': '艾莉老師的靜心哈達瑜珈（Hatha Yoga）週三晚上班 找回丟失的靜心和肌肉',
#   'during': '2020-08-26 ~ 2020-10-21',
#   'hours': '8',
#   'location': '大安中心',
#   'price': ' 4,690',
#   'time': '(三) 19:00-20:00',
#   'weekday': '2020-08-26 ~ 2020-10-21',
#   'today': '2020-07-30'},
#  {'title': '兒少藝術療育：跟榮格的藝術視野學情緒教養 藝術教育博士、專業藝術治療師徐玟玲老師親授',
#   'during': '2020-08-30 ~ 2020-09-27',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 7,200',
#   'time': '日 10:00~17:00',
#   'weekday': '2020-08-30 ~ 2020-09-27',
#   'today': '2020-07-30'},
#  {'title': '艾莉老師的靜心哈達瑜珈（Hatha Yoga）周二下午班 找回丟失的靜心和肌肉',
#   'during': '2020-09-01 ~ 2020-10-20',
#   'hours': '8',
#   'location': '大安中心',
#   'price': ' 4,690',
#   'time': '(二) 13:30-14:30',
#   'weekday': '2020-09-01 ~ 2020-10-20',
#   'today': '2020-07-30'},
#  {'title': '艾莉老師的和緩流暢瑜珈（Flow Yoga）周二下午班 喚醒你的核心與肌力',
#   'during': '2020-09-01 ~ 2020-10-20',
#   'hours': '8',
#   'location': '大安中心',
#   'price': ' 4,690',
#   'time': '(二) 14:45-15:45',
#   'weekday': '2020-09-01 ~ 2020-10-20',
#   'today': '2020-07-30'},
#  {'title': '艾莉老師的午休伸展瑜珈～周二午休班 消除肌肉緊繃，回復柔軟線條',
#   'during': '2020-09-01 ~ 2020-10-20',
#   'hours': '8',
#   'location': '大安中心',
#   'price': ' 4,690',
#   'time': '(二) 12:00-13:00',
#   'weekday': '2020-09-01 ~ 2020-10-20',
#   'today': '2020-07-30'},
#  {'title': 'NAHA美國整體芳療師認證-初階I 踏入專業芳療的第一步<名額有限,精緻小班>',
#   'during': '2020-09-01 ~ 2020-10-06',
#   'hours': '32',
#   'location': '華岡大安中心',
#   'price': ' 8,500',
#   'time': '二10:00~17:00',
#   'weekday': '2020-09-01 ~ 2020-10-06',
#   'today': '2020-07-30'},
#  {'title': '母嬰照護認證聯合說明會',
#   'during': '2020-09-06 ~ 2020-09-06',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '日 10:00~12:00',
#   'weekday': '2020-09-06 ~ 2020-09-06',
#   'today': '2020-07-30'},
#  {'title': '失落情緒議題銀髮族藝術陪伴與自我照顧',
#   'during': '2020-09-06 ~ 2020-11-01',
#   'hours': '24',
#   'location': '福華國際文教會館',
#   'price': ' 6,720',
#   'time': '日 10:00~17:00',
#   'weekday': '2020-09-06 ~ 2020-11-01',
#   'today': '2020-07-30'},
#  {'title': '艾莉老師的午休舒心瑜珈～周一午休班',
#   'during': '2020-09-07 ~ 2020-10-26',
#   'hours': '8',
#   'location': '大安中心',
#   'price': ' 4,690',
#   'time': '(一) 12:00-13:00',
#   'weekday': '2020-09-07 ~ 2020-10-26',
#   'today': '2020-07-30'},
#  {'title': '月子管理師培訓班初階班 平日密集班',
#   'during': '2020-09-07 ~ 2020-09-14',
#   'hours': '24',
#   'location': '華岡大安中心',
#   'price': ' 8,800',
#   'time': '一、三、五 09:00~16:00',
#   'weekday': '2020-09-07 ~ 2020-09-14',
#   'today': '2020-07-30'},
#  {'title': 'BSS寶寶音樂手語檢定證照課程 讓還不會說話的寶寶也能與您溝通',
#   'during': '2020-09-08 ~ 2020-09-29',
#   'hours': '8',
#   'location': '華岡大安中心',
#   'price': ' 3,500',
#   'time': '二 10:00~12:00',
#   'weekday': '2020-09-08 ~ 2020-09-29',
#   'today': '2020-07-30'},
#  {'title': '專業經絡師培訓營 免費說明會 一技之長在手無可取代價值',
#   'during': '2020-09-08 ~ 2020-09-08',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '二 14:00~16:00',
#   'weekday': '2020-09-08 ~ 2020-09-08',
#   'today': '2020-07-30'},
#  {'title': '香氛紓壓活絡術 變身芳香舒壓達人',
#   'during': '2020-09-09 ~ 2020-10-07',
#   'hours': '30',
#   'location': '大安中心',
#   'price': ' 8,250',
#   'time': '三 09:30~16:30',
#   'weekday': '2020-09-09 ~ 2020-10-07',
#   'today': '2020-07-30'},
#  {'title': 'NAHA美國整體芳療師認證-初階II 專業芳療進階',
#   'during': '2020-09-10 ~ 2020-10-22',
#   'hours': '32',
#   'location': '華岡大安中心',
#   'price': ' 9,000',
#   'time': '四 10:00~17:00',
#   'weekday': '2020-09-10 ~ 2020-10-22',
#   'today': '2020-07-30'},
#  {'title': '銀髮族芳療與經絡按摩照護班 可累計長照積分12點結合中西方照護的養生方式，舒緩老化或慢性疾病',
#   'during': '2020-09-10 ~ 2020-10-22',
#   'hours': '12',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '(四)09:30~11:30',
#   'weekday': '2020-09-10 ~ 2020-10-22',
#   'today': '2020-07-30'},
#  {'title': '芳香輕療癒-十二時辰養生法 幫身體「在正確時間做正確的事」',
#   'during': '2020-09-12 ~ 2020-09-12',
#   'hours': '3',
#   'location': '華岡大安中心',
#   'price': ' 750',
#   'time': '六09:30~12:30',
#   'weekday': '2020-09-12 ~ 2020-09-12',
#   'today': '2020-07-30'},
#  {'title': '從心彩繪曼陀羅-體驗工作坊 沒有畫畫基礎也可以參加!!',
#   'during': '2020-09-12 ~ 2020-09-12',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 350',
#   'time': '(六) 10:00-12:00',
#   'weekday': '2020-09-12 ~ 2020-09-12',
#   'today': '2020-07-30'},
#  {'title': 'NAHA美國整體芳療師認證-高階I學科 成為專業芳療師',
#   'during': '2020-09-15 ~ 2021-01-05',
#   'hours': '83',
#   'location': '大安中心',
#   'price': ' 25,000',
#   'time': '二10:00~17:00',
#   'weekday': '2020-09-15 ~ 2021-01-05',
#   'today': '2020-07-30'},
#  {'title': '月子管理師培訓班進階班 平日密集班',
#   'during': '2020-09-16 ~ 2020-09-23',
#   'hours': '24',
#   'location': '華岡大安中心',
#   'price': ' 8,800',
#   'time': '一、三、五 09:00~16:00',
#   'weekday': '2020-09-16 ~ 2020-09-23',
#   'today': '2020-07-30'},
#  {'title': '芳香輕療癒-斷捨離，減法過新生 香氛開運小妙方',
#   'during': '2020-09-19 ~ 2020-09-19',
#   'hours': '3',
#   'location': '華岡大安中心',
#   'price': ' 750',
#   'time': '六 09:30~12:30',
#   'weekday': '2020-09-19 ~ 2020-09-19',
#   'today': '2020-07-30'},
#  {'title': '從心彩繪曼陀羅-體驗工作坊 沒有畫畫基礎也可以參加!!',
#   'during': '2020-09-21 ~ 2020-09-21',
#   'hours': '2',
#   'location': '華岡大安中心',
#   'price': ' 350',
#   'time': '(一) 19:00-21:00',
#   'weekday': '2020-09-21 ~ 2020-09-21',
#   'today': '2020-07-30'},
#  {'title': '兒童及青少年正念曼陀羅繪畫療育職能培訓 療育系名師童玉娟老師親自授課',
#   'during': '2020-09-22 ~ 2020-11-03',
#   'hours': '18',
#   'location': '華岡大安中心',
#   'price': ' 7,200',
#   'time': '二 19:00~22:00',
#   'weekday': '2020-09-22 ~ 2020-11-03',
#   'today': '2020-07-30'},
#  {'title': '專業經絡師培訓營 週日班班爆滿，可回訓',
#   'during': '2020-09-29 ~ 2020-11-03',
#   'hours': '70',
#   'location': '華岡大安中心',
#   'price': ' 36,000',
#   'time': '二 09:30~17:30',
#   'weekday': '2020-09-29 ~ 2020-11-03',
#   'today': '2020-07-30'},
# ...
#   'location': '華岡大安中心',
#   'price': ' 12,000',
#   'time': '四19:00~22:00',
#   'weekday': '2020-09-10 ~ 2020-11-05',
#   'today': '2020-07-30'},
#  {'title': '楊比比攝影人2020 數位攝影暗房攻略 基礎班 確定開班',
#   'during': '2020-09-19 ~ 2020-09-19',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 2,500',
#   'time': '六 10:00~17:00',
#   'weekday': '2020-09-19 ~ 2020-09-19',
#   'today': '2020-07-30'},
#  {'title': '美甲控必學！凝膠指甲 午後時光小班教學名額有限',
#   'during': '2020-10-13 ~ 2020-11-24',
#   'hours': '21',
#   'location': '華岡大安中心',
#   'price': ' 4,800',
#   'time': '二 14:00-17:00',
#   'weekday': '2020-10-13 ~ 2020-11-24',
#   'today': '2020-07-30'},
#  {'title': 'Color4 IMAGE 專業時尚品味顧問培訓(假日班) 基礎培訓班--日本JPCA專業個人色彩分析師 + 國際專利Color4 IMAGE 品味座標法 雙認證',
#   'during': '2020-10-17 ~ 2020-11-29',
#   'hours': '40',
#   'location': '台北市大安區106永康街75巷8號5樓之2',
#   'price': ' 56,000',
#   'time': '10:00~17:00(中間休息1小時)',
#   'weekday': '2020-10-17 ~ 2020-11-29',
#   'today': '2020-07-30'},
#  {'title': 'Color4 IMAGE 專業時尚品味顧問培訓(密集班) 基礎培訓班--日本JPCA專業個人色彩分析師 + 國際專利Color4 IMAGE 品味座標法 雙認證',
#   'during': '2020-10-20 ~ 2020-12-03',
#   'hours': '40',
#   'location': '台北市大安區106永康街75巷8號5樓之2',
#   'price': ' 56,000',
#   'time': '10/20-10/22(二~四)；12/1-12/3(二~四)10:00~17:00(中間休息1小時)',
#   'weekday': '2020-10-20 ~ 2020-12-03',
#   'today': '2020-07-30'},
#  {'title': '策展經理人培訓',
#   'during': '2020-11-01 ~ 2020-12-06',
#   'hours': '48',
#   'location': '華岡大安中心',
#   'price': ' 24,000',
#   'time': '日 09:30~16:30',
#   'weekday': '2020-11-01 ~ 2020-12-06',
#   'today': '2020-07-30'},
#  {'title': '天然精油調香藝術初階班 學費含材料費!',
#   'during': '2020-11-10 ~ 2020-12-29',
#   'hours': '24',
#   'location': '華岡大安中心',
#   'price': ' 12,000',
#   'time': '二14:00~17:00',
#   'weekday': '2020-11-10 ~ 2020-12-29',
#   'today': '2020-07-30'},
#  {'title': 'Color4 IMAGE個人色彩分析師培訓 日本JPCA色彩技能國際認證(假日密集班)',
#   'during': '2020-11-27 ~ 2020-11-29',
#   'hours': '20',
#   'location': '台北市大安區106永康街75巷8號5樓之2',
#   'price': ' 28,000',
#   'time': '五、六、日10:00~16:00(中間休息1小時)',
#   'weekday': '2020-11-27 ~ 2020-11-29',
#   'today': '2020-07-30'},
#  {'title': 'Color4 IMAGE個人色彩分析師培訓 日本JPCA色彩技能國際認證(平日密集班)',
#   'during': '2020-12-01 ~ 2020-12-03',
#   'hours': '20',
#   'location': '台北市大安區106永康街75巷8號5樓之2',
#   'price': ' 28,000',
#   'time': '二、三、四10:00~16:00(中間休息1小時)',
#   'weekday': '2020-12-01 ~ 2020-12-03',
#   'today': '2020-07-30'},
#  {'title': '天然精油調香藝術進階班 調香更得心應手! 渾然天成!',
#   'during': '2021-03-07 ~ 2021-05-23',
#   'hours': '30',
#   'location': '華岡大安中心',
#   'price': ' 15,000',
#   'time': '日14:00~17:00',
#   'weekday': '2021-03-07 ~ 2021-05-23',
#   'today': '2020-07-30'},
#  {'title': '天然精油調香藝術進階班 調香更得心應手! 渾然天成!',
#   'during': '2021-05-11 ~ 2021-07-13',
#   'hours': '30',
#   'location': '華岡大安中心',
#   'price': ' 15,000',
#   'time': '二 14:00~17:00',
#   'weekday': '2021-05-11 ~ 2021-07-13',
#   'today': '2020-07-30'},
#  {'title': '天然精油調香藝術高階班 調配出一瓶專屬的香氣身份證',
#   'during': '2021-09-16 ~ 2021-12-16',
#   'hours': '36',
#   'location': '華岡大安中心',
#   'price': ' 18,000',
#   'time': '四 14:00~17:00',
#   'weekday': '2021-09-16 ~ 2021-12-16',
#   'today': '2020-07-30'},
#  {'title': '從分析到機器學習:Level_Ⅰ NO CODE 不寫程式機器學習',
#   'during': '2020-07-25 ~ 2020-07-26',
#   'hours': '12',
#   'location': '華岡大安中心',
#   'price': ' 18,900',
#   'time': '六 日 09:30-16:30',
#   'weekday': '2020-07-25 ~ 2020-07-26',
#   'today': '2020-07-30'},
#  {'title': '從分析到機器學習 NO CODE 不寫程式機器學習',
#   'during': '2020-07-25 ~ 2020-08-02',
#   'hours': '24',
#   'location': '華岡大安中心',
#   'price': ' 37,800',
#   'time': '六 日 09:30-16:30',
#   'weekday': '2020-07-25 ~ 2020-08-02',
#   'today': '2020-07-30'},
#  {'title': 'Python 數據資料分析師入門班',
#   'during': '2020-08-07 ~ 2020-09-25',
#   'hours': '24',
#   'location': '福華會館公務人力發展中心',
#   'price': ' 15,000',
#   'time': '五18:30-21:30',
#   'weekday': '2020-08-07 ~ 2020-09-25',
#   'today': '2020-07-30'},
#  {'title': 'OpenCV影像辨識與機器學習',
#   'during': '2020-08-14 ~ 2020-08-15',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 3,800',
#   'time': '五 六18:30~21:30',
#   'weekday': '2020-08-14 ~ 2020-08-15',
#   'today': '2020-07-30'},
#  {'title': '白帽駭客認知班 AI/Big Data技能養成班系列課程:確定開班',
#   'during': '2020-08-14 ~ 2020-08-14',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 4,800',
#   'time': '五 09:30-16:30',
#   'weekday': '2020-08-14 ~ 2020-08-14',
#   'today': '2020-07-30'},
#  {'title': '區塊鏈入門實務班 AI/Big Data技能養成班系列課程:確定開班',
#   'during': '2020-08-15 ~ 2020-08-16',
#   'hours': '12',
#   'location': '華岡大安中心',
#   'price': ' 9,600',
#   'time': '六日 09:30-16:30',
#   'weekday': '2020-08-15 ~ 2020-08-16',
#   'today': '2020-07-30'},
#  {'title': 'AI/BIG DATA大數據技能養成班 第11期熱烈招生中 成為最搶手的關鍵人才',
#   'during': '2020-08-17 ~ 2021-01-31',
#   'hours': '680',
#   'location': '華岡大安中心',
#   'price': ' 140,000',
#   'time': '一~五 09:30-16:30',
#   'weekday': '2020-08-17 ~ 2021-01-31',
#   'today': '2020-07-30'},
#  {'title': 'Java菁英養成專班',
#   'during': '2020-09-01 ~ 2021-01-31',
#   'hours': '600',
#   'location': '華岡大安中心',
#   'price': ' 136,000',
#   'time': '一二三四五 09:30-16:30',
#   'weekday': '2020-09-01 ~ 2021-01-31',
#   'today': '2020-07-30'},
#  {'title': 'Python 數據資料分析師入門班',
#   'during': '2020-10-23 ~ 2020-12-11',
#   'hours': '24',
#   'location': '福華會館公務人力發展中心',
#   'price': ' 15,000',
#   'time': '五18:30-21:30',
#   'weekday': '2020-10-23 ~ 2020-12-11',
#   'today': '2020-07-30'},
#  {'title': 'HR人資商學院第二屆︱HR Growth Hacker',
#   'during': '2020-07-25 ~ 2020-09-19',
#   'hours': '25',
#   'location': '為你而讀',
#   'price': ' 4,000',
#   'time': '六 日 10:00～17:00',
#   'weekday': '2020-07-25 ~ 2020-09-19',
#   'today': '2020-07-30'},
#  {'title': 'CMA國際管理會計師證照考照 Wiley CMA 教材+48小時面授課程(本期加贈20小時考前輔導)',
#   'during': '2020-07-26 ~ 2020-09-20',
#   'hours': '68',
#   'location': '華岡大安中心',
#   'price': ' 88,000',
#   'time': '日 09:30~16:30',
#   'weekday': '2020-07-26 ~ 2020-09-20',
#   'today': '2020-07-30'},
#  {'title': '商務談判第一次就上手',
#   'during': '2020-07-26 ~ 2020-07-26',
#   'hours': '6',
#   'location': '公務人力發展中心-福華國際文教會館',
#   'price': ' 3,600',
#   'time': '日 10:00-17:00',
#   'weekday': '2020-07-26 ~ 2020-07-26',
#   'today': '2020-07-30'},
#  {'title': '美國註冊會計師(CPA)證照班-舊生專案REG',
#   'during': '2020-08-01 ~ 2020-12-19',
#   'hours': '196',
#   'location': '華岡大安中心',
#   'price': ' 48,000',
#   'time': '二19:00~21:30;六09:00~12:00;13:00~16:00',
#   'weekday': '2020-08-01 ~ 2020-12-19',
#   'today': '2020-07-30'},
#  {'title': '策略性人力資源管理師認證班',
#   'during': '2020-08-02 ~ 2020-09-06',
#   'hours': '36',
#   'location': '台北市大安區',
#   'price': ' 17,500',
#   'time': '日09:00～16:00',
#   'weekday': '2020-08-02 ~ 2020-09-06',
#   'today': '2020-07-30'},
#  {'title': '會計入門 抓出營運問題，制訂有效決策',
#   'during': '2020-08-04 ~ 2020-08-27',
#   'hours': '20',
#   'location': '公務人力發展中心-福華文教會館',
#   'price': ' 6,000',
#   'time': '二 四 19:00-21:30',
#   'weekday': '2020-08-04 ~ 2020-08-27',
#   'today': '2020-07-30'},
#  {'title': '溝通跨越力養成班 從六歲到七八十歲，從小孩到公司老闆，都能有效溝通！再兩位開班',
#   'during': '2020-08-04 ~ 2020-09-01',
#   'hours': '10',
#   'location': '華岡大安中心',
#   'price': ' 7,600',
#   'time': '二 19:30~21:30',
#   'weekday': '2020-08-04 ~ 2020-09-01',
#   'today': '2020-07-30'},
#  {'title': '員工心理諮商輔導人員認證班',
#   'during': '2020-08-16 ~ 2020-09-13',
#   'hours': '30',
#   'location': '台北市大安區',
#   'price': ' 11,900',
#   'time': '日 09:00～16:00',
#   'weekday': '2020-08-16 ~ 2020-09-13',
#   'today': '2020-07-30'},
#  {'title': '視覺圖像設計與溝通表達',
#   'during': '2020-08-22 ~ 2020-08-29',
#   'hours': '12',
#   'location': '福華會館 公務人力發展中心',
#   'price': ' 8,800',
#   'time': '六； 9:30~16:30',
#   'weekday': '2020-08-22 ~ 2020-08-29',
#   'today': '2020-07-30'},
#  {'title': '休閒農業經營管理班 政府補助：$2880，參訓學員自行負擔：$720',
#   'during': '2020-08-25 ~ 2020-09-22',
#   'hours': '27',
#   'location': '福華國際文教會館',
#   'price': ' 3,600',
#   'time': '二 四 18:30~21:30',
#   'weekday': '2020-08-25 ~ 2020-09-22',
#   'today': '2020-07-30'},
#  {'title': '財務報表分析全修班',
#   'during': '2020-09-09 ~ 2020-09-30',
#   'hours': '12',
#   'location': '華岡大安中心',
#   'price': ' 4,800',
#   'time': '三 18:50-21:50',
#   'weekday': '2020-09-09 ~ 2020-09-30',
#   'today': '2020-07-30'},
#  {'title': '美國註冊會計師(CPA)證照班',
#   'during': '2020-09-12 ~ 2021-05-15',
#   'hours': '196',
#   'location': '華岡大安中心',
#   'price': ' 80,000',
#   'time': '二19:00~21:30;六09:00~12:00;13:00~16:00',
#   'weekday': '2020-09-12 ~ 2021-05-15',
#   'today': '2020-07-30'},
#  {'title': '美國註冊會計師(CPA)證照班-舊生專案FAR',
#   'during': '2020-09-12 ~ 2021-05-15',
#   'hours': '196',
#   'location': '華岡大安中心',
#   'price': ' 48,000',
#   'time': '二19:00~21:30;六09:00~12:00;13:00~16:00',
#   'weekday': '2020-09-12 ~ 2021-05-15',
#   'today': '2020-07-30'},
#  {'title': 'AVM作業價值管理師 破除成本迷思，掌握企業決策 第二期熱烈招生中',
#   'during': '2020-09-19 ~ 2020-10-31',
#   'hours': '24',
#   'location': '福華文教會館',
#   'price': ' 15,000',
#   'time': '六 09:30-16:30',
#   'weekday': '2020-09-19 ~ 2020-10-31',
#   'today': '2020-07-30'},
#  {'title': 'BCC國際認證專業教練高階領導教練的價值 企業成功方程式－免費課程說明會－',
#   'during': '2020-09-20 ~ 2020-09-20',
#   'hours': '2',
#   'location': '公務人力發展中心福華會館',
#   'price': ' 0',
#   'time': '日 14:00~16:00',
#   'weekday': '2020-09-20 ~ 2020-09-20',
#   'today': '2020-07-30'},
#  {'title': 'BCC國際認證專業教練國際證照培訓班－台北班 ★啟動潛能激發、邁向致勝職涯★',
#   'during': '2020-10-18 ~ 2020-12-20',
#   'hours': '62',
#   'location': '台北福華',
#   'price': ' 65,000',
#   'time': '日',
#   'weekday': '2020-10-18 ~ 2020-12-20',
#   'today': '2020-07-30'},
#  {'title': '英國City & Guilds行銷管理師(銷售)國際證照輔考課程',
#   'during': '2020-10-24 ~ 2020-11-07',
#   'hours': '18',
#   'location': '公務人力發展中心福華國際文教會館',
#   'price': ' 12,600',
#   'time': '六， 09:30~16:30',
#   'weekday': '2020-10-24 ~ 2020-11-07',
#   'today': '2020-07-30'},
#  {'title': '商務談判第一次就上手',
#   'during': '2020-10-25 ~ 2020-10-25',
#   'hours': '6',
#   'location': '公務人力發展中心-福華國際文教會館',
#   'price': ' 3,600',
#   'time': '日 10:00-17:00',
#   'weekday': '2020-10-25 ~ 2020-10-25',
#   'today': '2020-07-30'},
#  {'title': 'CMA國際管理會計師證照考照 Wiley CMA 教材+48小時面授課程(本期加贈20小時考前輔導)',
#   'during': '2020-11-01 ~ 2020-12-27',
#   'hours': '68',
#   'location': '華岡大安中心',
#   'price': ' 88,000',
#   'time': '日 09:30~16:30',
#   'weekday': '2020-11-01 ~ 2020-12-27',
#   'today': '2020-07-30'},
#  {'title': '會計入門 抓出營運問題，制訂有效決策',
#   'during': '2020-11-02 ~ 2020-11-25',
#   'hours': '20',
#   'location': '公務人力發展中心-福華文教會館',
#   'price': ' 6,000',
#   'time': '一三19:00-21:30',
#   'weekday': '2020-11-02 ~ 2020-11-25',
#   'today': '2020-07-30'},
#  {'title': '財務報表分析全修班',
#   'during': '2020-11-04 ~ 2020-11-25',
#   'hours': '12',
#   'location': '華岡大安中心',
#   'price': ' 4,800',
#   'time': '三 18:50-21:50',
#   'weekday': '2020-11-04 ~ 2020-11-25',
#   'today': '2020-07-30'},
#  {'title': 'CGAP總務採購管理師認證班-台中班',
#   'during': '2020-11-07 ~ 2020-12-05',
#   'hours': '30',
#   'location': '台中文創館：台中市西區台灣大道2段2號13F-1',
#   'price': ' 11,000',
#   'time': '六 09:30~16:30',
#   'weekday': '2020-11-07 ~ 2020-12-05',
#   'today': '2020-07-30'},
#  {'title': 'SEO策劃師培訓認證 數位行銷專家的第一步',
#   'during': '2020-11-07 ~ 2020-12-12',
#   'hours': '36',
#   'location': '公務人力發展中心-福華文教會館',
#   'price': ' 21,600',
#   'time': '六 10:00-17:00',
#   'weekday': '2020-11-07 ~ 2020-12-12',
#   'today': '2020-07-30'},
#  {'title': '英國City&Guilds顧客關係管理師(顧客服務)證照課程',
#   'during': '2020-11-14 ~ 2020-11-21',
#   'hours': '12',
#   'location': '公務人力發展中心福華國際文教會館',
#   'price': ' 8,400',
#   'time': '六 9:30~16:30',
#   'weekday': '2020-11-14 ~ 2020-11-21',
#   'today': '2020-07-30'},
#  {'title': 'CCE國際證照 BCC國際認證費 BCC國際證照費',
#   'during': '2020-12-01 ~ 2020-12-31',
#   'hours': '0',
#   'location': '',
#   'price': ' 5,000',
#   'time': '',
#   'weekday': '2020-12-01 ~ 2020-12-31',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家免費分享會',
#   'during': '2020-07-26 ~ 2020-07-26',
#   'hours': '2',
#   'location': '福華文教會館',
#   'price': ' 0',
#   'time': '日 14:00-16:00',
#   'weekday': '2020-07-26 ~ 2020-07-26',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家初階班 假日班',
#   'during': '2020-08-01 ~ 2020-08-02',
#   'hours': '5',
#   'location': 'investU線上社大 台北教室',
#   'price': ' 11,000',
#   'time': '六 日 18:00-20:30',
#   'weekday': '2020-08-01 ~ 2020-08-02',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家全修班',
#   'during': '2020-08-01 ~ 2020-10-25',
#   'hours': '25',
#   'location': 'investU線上社大 台北教室',
#   'price': ' 72,800',
#   'time': '六 日 18:00-20:30',
#   'weekday': '2020-08-01 ~ 2020-10-25',
#   'today': '2020-07-30'},
#  {'title': '共有土地開發 開發處份與分割實務',
#   'during': '2020-08-04 ~ 2020-08-24',
#   'hours': '12',
#   'location': '創世紀國際不動產管理顧問有限公司 (台北市信義區信義路四段415號8樓之5)',
#   'price': ' 6,800',
#   'time': '二 18:50~21:30 ; 一 18:50~21:30',
#   'weekday': '2020-08-04 ~ 2020-08-24',
#   'today': '2020-07-30'},
#  {'title': 'Smart理財股票策略: 布局防疫新商機の菁英投資高峰論壇',
#   'during': '2020-08-08 ~ 2020-08-08',
#   'hours': '3',
#   'location': '華岡大安中心',
#   'price': ' 0',
#   'time': '六 14:00～17:00',
#   'weekday': '2020-08-08 ~ 2020-08-08',
#   'today': '2020-07-30'},
#  {'title': '2天讓您學會法拍屋致富實戰',
#   'during': '2020-08-10 ~ 2020-08-17',
#   'hours': '6',
#   'location': '創世紀國際不動產管理顧問有限公司 (台北市信義區信義路四段415號8樓之5)',
#   'price': ' 3,800',
#   'time': '一18:50~21:30',
#   'weekday': '2020-08-10 ~ 2020-08-17',
#   'today': '2020-07-30'},
#  {'title': '外匯致勝方程式 掌握外匯市場投資致勝關鍵',
#   'during': '2020-08-12 ~ 2020-08-19',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '三 19:00-22:00',
#   'weekday': '2020-08-12 ~ 2020-08-19',
#   'today': '2020-07-30'},
#  {'title': '買屋價值鑑定實務班 10小時練就「好宅」眼光力',
#   'during': '2020-08-18 ~ 2020-09-05',
#   'hours': '10',
#   'location': '公務人力發展中心福華文教會館',
#   'price': ' 5,000',
#   'time': '二 19:00-21:30 六 13:30-16:00',
#   'weekday': '2020-08-18 ~ 2020-09-05',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家免費分享會',
#   'during': '2020-08-20 ~ 2020-08-20',
#   'hours': '2',
#   'location': '福華文教會館',
#   'price': ' 0',
#   'time': '四 18:40-20:30',
#   'weekday': '2020-08-20 ~ 2020-08-20',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家免費分享會',
#   'during': '2020-08-23 ~ 2020-08-23',
#   'hours': '2',
#   'location': '福華文教會館',
#   'price': ' 0',
#   'time': '日 14:00-16:00',
#   'weekday': '2020-08-23 ~ 2020-08-23',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家初階班 平日班',
#   'during': '2020-08-29 ~ 2020-08-29',
#   'hours': '5',
#   'location': 'investU線上社大 台北教室',
#   'price': ' 11,000',
#   'time': '六 10:00-16:00',
#   'weekday': '2020-08-29 ~ 2020-08-29',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家中階班',
#   'during': '2020-09-05 ~ 2020-09-12',
#   'hours': '10',
#   'location': 'investU線上社大 台北教室',
#   'price': ' 22,000',
#   'time': '六 10:00-16:00',
#   'weekday': '2020-09-05 ~ 2020-09-12',
#   'today': '2020-07-30'},
#  {'title': '股市投資實戰初階 杜老師帶你判斷未來走勢',
#   'during': '2020-09-09 ~ 2020-09-30',
#   'hours': '10',
#   'location': '華岡大安中心',
#   'price': ' 6,000',
#   'time': '三 13:40-16:10',
#   'weekday': '2020-09-09 ~ 2020-09-30',
#   'today': '2020-07-30'},
#  {'title': '不動產法律實戰班 排除地上物及共有土地處分法律實戰',
#   'during': '2020-09-17 ~ 2020-09-24',
#   'hours': '6',
#   'location': '創世紀國際不動產管理顧問有限公司 (台北市信義區信義路四段415號8樓之5)',
#   'price': ' 3,800',
#   'time': '四 18:50~21:30',
#   'weekday': '2020-09-17 ~ 2020-09-24',
#   'today': '2020-07-30'},
#  {'title': '第一次買房就上手 最佳買房成功術',
#   'during': '2020-09-23 ~ 2020-10-28',
#   'hours': '20',
#   'location': '公務人力發展中心-福華文教會館',
#   'price': ' 8,000',
#   'time': '三 19:00-21:30',
#   'weekday': '2020-09-23 ~ 2020-10-28',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家免費分享會',
#   'during': '2020-09-24 ~ 2020-09-24',
#   'hours': '2',
#   'location': '福華文教會館',
#   'price': ' 0',
#   'time': '四 18:40-20:30',
#   'weekday': '2020-09-24 ~ 2020-09-24',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家免費分享會',
#   'during': '2020-09-27 ~ 2020-09-27',
#   'hours': '2',
#   'location': '福華文教會館',
#   'price': ' 0',
#   'time': '日 14:00-16:00',
#   'weekday': '2020-09-27 ~ 2020-09-27',
#   'today': '2020-07-30'},
#  {'title': 'ETF新手變行家高階班',
#   'during': '2020-10-18 ~ 2020-10-25',
#   'hours': '10',
#   'location': 'investU線上社大 台北教室',
#   'price': ' 69,800',
#   'time': '日 10:00-16:00',
#   'weekday': '2020-10-18 ~ 2020-10-25',
#   'today': '2020-07-30'},
#  {'title': '外匯致勝方程式 掌握外匯市場投資致勝關鍵',
#   'during': '2020-11-11 ~ 2020-11-18',
#   'hours': '6',
#   'location': '華岡大安中心',
#   'price': ' 3,600',
#   'time': '三 19:00-22:00',
#   'weekday': '2020-11-11 ~ 2020-11-18',
#   'today': '2020-07-30'},
#  {'title': '第一次買房就上手 最佳買房成功術',
#   'during': '2020-11-11 ~ 2020-12-30',
#   'hours': '20',
#   'location': '公務人力發展中心-福華文教會館',
#   'price': ' 8,000',
#   'time': '三 19:00-21:30',
#   'weekday': '2020-11-11 ~ 2020-12-30',
#   'today': '2020-07-30'},
#  {'title': '股市投資實戰初階 杜老師帶你判斷未來走勢',
#   'during': '2020-12-02 ~ 2020-12-23',
#   'hours': '10',
#   'location': '華岡大安中心',
#   'price': ' 6,000',
#   'time': '三 13:40-16:10',
#   'weekday': '2020-12-02 ~ 2020-12-23',
#   'today': '2020-07-30'}]

# %%
engine = create_engine(f'mysql+pymysql://allen:allen0319@192.168.56.150:3306/education?charset=utf8')
sql = "SELECT * FROM main;"
df = pd.read_sql(sql,engine)
df["hours"] = df.hours.astype("float32")
df['price'] = df['price'].map(lambda name: name.replace(",",""))
df['price'] = df['price'].astype('int')
df
# Out:
#                                        title                   during  hours  \
# 0    英國巴哈情緒花精&美國NAHA芳療師 聯合說明會 一次學習，全家受惠，終身受用  2020-08-06 ~ 2020-08-06    1.5
# 1                   CDU系列個案實戰演練課程_台中班 －個案討論會  2020-08-09 ~ 2020-08-09    7.0
# 2                      芳療精油洞悉卡諮詢工作坊 引導對話內在能量  2020-08-09 ~ 2020-08-23   18.0
# 3                               美國會計師證照課程說明會  2020-08-14 ~ 2020-08-14    1.0
# 4              CDU系列聽話、問話、結構化－個案概念化 晤談力初階練功坊  2020-08-15 ~ 2020-08-15    6.0
# ..                                       ...                      ...    ...
# 359                            ETF新手變行家免費分享會  2020-09-27 ~ 2020-09-27    2.0
# 360                              ETF新手變行家高階班  2020-10-18 ~ 2020-10-25   10.0
# 361                     外匯致勝方程式 掌握外匯市場投資致勝關鍵  2020-11-11 ~ 2020-11-18    6.0
# 362                         第一次買房就上手 最佳買房成功術  2020-11-11 ~ 2020-12-30   20.0
# 363                     股市投資實戰初階 杜老師帶你判斷未來走勢  2020-12-02 ~ 2020-12-23   10.0
#
#                                 location  price           time  \
# 0                                 華岡大安中心      0  四 14:00~15:30
# 1    台中東海大學－臺中市臺灣大道四段1727號管理大樓 東海大學第二教學區   4000    09-12；13-17
# 2                                 華岡大安中心   9999   日10:00~17:00
# 3                                 華岡大安中心      0    19:00~20:00
# 4                      高雄市三民區博愛一路366號14樓   4000    09-12；13-16
# ..                                   ...    ...            ...
# 359                               福華文教會館      0  日 14:00-16:00
# 360                     investU線上社大 台北教室  69800  日 10:00-16:00
# 361                               華岡大安中心   3600  三 19:00-22:00
# 362                      公務人力發展中心-福華文教會館   8000  三 19:00-21:30
# 363                               華岡大安中心   6000  三 13:40-16:10
#
#                      weekday       today
# 0    2020-08-06 ~ 2020-08-06  2020-07-30
# 1    2020-08-09 ~ 2020-08-09  2020-07-30
# 2    2020-08-09 ~ 2020-08-23  2020-07-30
# 3    2020-08-14 ~ 2020-08-14  2020-07-30
# 4    2020-08-15 ~ 2020-08-15  2020-07-30
# ..                       ...         ...
# 359  2020-09-27 ~ 2020-09-27  2020-07-30
# 360  2020-10-18 ~ 2020-10-25  2020-07-30
# 361  2020-11-11 ~ 2020-11-18  2020-07-30
# 362  2020-11-11 ~ 2020-12-30  2020-07-30
# 363  2020-12-02 ~ 2020-12-23  2020-07-30
#
# [364 rows x 8 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     364 non-null    object
#  1   during    364 non-null    object
#  2   hours     364 non-null    float32
#  3   location  364 non-null    object
#  4   price     364 non-null    int64
#  5   time      364 non-null    object
#  6   weekday   364 non-null    object
#  7   today     364 non-null    object
# dtypes: float32(1), int64(1), object(6)
# memory usage: 21.5+ KB

# %%
df['location'].tail(60)
# Out:
# 317                     台北市大安區106永康街75巷8號5樓之2
# 318                                    華岡大安中心
# 319                                    華岡大安中心
# 320                                    華岡大安中心
# 321                                    華岡大安中心
# 322                                    華岡大安中心
# 323                                    華岡大安中心
# 324                              福華會館公務人力發展中心
# 325                                    華岡大安中心
# 326                                    華岡大安中心
# 327                                    華岡大安中心
# 328                                    華岡大安中心
# 329                              福華會館公務人力發展中心
# 330                                    華岡大安中心
# 331                                      為你而讀
# 332                                    華岡大安中心
# 333                         公務人力發展中心-福華國際文教會館
# 334                                    台北市大安區
# 335                           公務人力發展中心-福華文教會館
# 336                                    華岡大安中心
# 337                                    台北市大安區
# 338                             福華會館 公務人力發展中心
# 339                                  福華國際文教會館
# 340                                    華岡大安中心
# 341                                    華岡大安中心
# 342                                    華岡大安中心
# 343                                    福華文教會館
# 344                                      台北福華
# 345                          公務人力發展中心福華國際文教會館
# 346                         公務人力發展中心-福華國際文教會館
# 347                                    華岡大安中心
# 348                           公務人力發展中心-福華文教會館
# 349                                    華岡大安中心
# 350                  台中文創館：台中市西區台灣大道2段2號13F-1
# 351                           公務人力發展中心-福華文教會館
# 352                          公務人力發展中心福華國際文教會館
# 353
# 354                              福華會館公務人力發展中心
# 355                                    福華文教會館
# 356                                    福華文教會館
# 357                          investU線上社大 台北教室
# 358                          investU線上社大 台北教室
# 359    創世紀國際不動產管理顧問有限公司 (台北市信義區信義路四段415號8樓之5)
# 360                                    華岡大安中心
# 361    創世紀國際不動產管理顧問有限公司 (台北市信義區信義路四段415號8樓之5)
# 362                                    華岡大安中心
# 363                            公務人力發展中心福華文教會館
# 364                                    福華文教會館
# 365                                    福華文教會館
# 366                          investU線上社大 台北教室
# 367                          investU線上社大 台北教室
# 368                                    華岡大安中心
# 369    創世紀國際不動產管理顧問有限公司 (台北市信義區信義路四段415號8樓之5)
# 370                           公務人力發展中心-福華文教會館
# 371                                    福華文教會館
# 372                                    福華文教會館
# 373                          investU線上社大 台北教室
# 374                                    華岡大安中心
# 375                           公務人力發展中心-福華文教會館
# 376                                    華岡大安中心
# Name: location, dtype: object

# %%
df['title'].values
# Out:
# array(['英國巴哈情緒花精&美國NAHA芳療師 聯合說明會 一次學習，全家受惠，終身受用', '芳療精油洞悉卡諮詢工作坊 引導對話內在能量',
#        '美國會計師證照課程說明會', 'CDU系列聽話、問話、結構化－個案概念化 晤談力初階練功坊', '英國巴哈情緒花精 心靈好防疫',
#        '英國巴哈情緒花精&美國NAHA芳療師 聯合說明會 一次學習，全家受惠，終身受用',
#        'CDU系列生命線x生涯卡x能力強項卡_台中班 －輔導工具練功坊一招就上手之簡易晤談工具',
#        'CGAP總務採購管理師認證班-台北班', '英國巴哈情緒花精&美國NAHA芳療師 聯合說明會 一次學習，全家受惠，終身受用',
#        'CDU玩樂高思人生－運用樂高六色積木與遊戲箱玩出職涯發展 -台中班', '英國巴哈情緒花精 解救那些不知所以的情緒輪迴',
#        'CCE國際證照 GCDF國際認證費 GCDF國際認證費,GCDF', '華岡證書線上繳費',
#        '大自然生態學苑2020華岡兒童夏令營 草山小學堂-擎天崗巡禮路線',
#        "兒童舞蹈教室 2020華岡兒童夏令營  MV流行街舞 Girls' Generation- Lion Heart",
#        '兒童理財營2020華岡兒童夏令營 富孩子養成計畫', '戳戳樂羊毛氈2020華岡兒童夏令營 我的動物朋友',
#        '高效讀書法2020華岡兒童夏令營 心智圖法筆記養成術', '小小料理達人2020華岡兒童夏令營 國際甜品大賞',
#        '兒童美術大師2020華岡兒童夏令營 神奇的寳貝們畫說藝術史', '小小藝術家創作營2020華岡兒童夏令營 公主風手作飾品',
#        '小紳士小淑女2020華岡兒童夏令營 品格養成x禮儀儀態', '兒童韓語班2020華岡兒童夏令營 Running Kids玩韓文',
#        '活力少年營隊APCS大學程式設計先修培訓 實力養成-基礎班。(第一梯次)',
#        '全日制 BTS 小小達人夏令營(第一梯)：不插電STEAM小達人（確定開班!） 邊玩邊學，快樂學習',
#        '律動英語AD+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#        'KK音標大挑戰2020華岡兒童夏令營 劍橋兒童英語(暑期英語技能養成班)',
#        '兒童課後照顧服務人員職前訓練課程 符合結訓資格，可領取台北市政府教育局證書',
#        '兒童美術師資認證輔導-台北班 超夯美術老師認證課程，歡迎加入美術老師行列額滿囉!!',
#        '兒童全腦開發訓練師認證輔導免費課程體驗及說明會', '小小魔術師2020華岡兒童夏令營 魔法的聖物',
#        '律動功夫營 2020華岡兒童夏令營  兒童防身術', '小小背包客2020華岡兒童夏令營 小文青相機之旅',
#        '小小料理達人2020華岡兒童夏令營 法國烘培時光屋',
#        '兒童珠寶設計師2020華岡兒童夏令營 女孩的手作珠寶(糖果屋裡的鑽石花園)', '看卡通學漫畫2020華岡兒童夏令營',
#        '指尖藝術繪粉彩2020華岡兒童夏令營 夏日踏青時光',
#        '小小哲學家2020華岡兒童夏令營 蘇格拉底的創意啟發-結合手作、桌遊、角色扮演的思辨遊戲',
#        '律動英語EH+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#        '創意Mini車床大師2020華岡兒童夏令營 百變文具機器人',
#        '小小全美語音樂劇表演課-受孩子們喜愛的音樂劇歌曲故事精選 7月Rapunzel高塔公主班',
#        '大自然生態學苑2020華岡兒童夏令營 草山小學堂-小油坑探索路線',
#        '兒童舞蹈教室 2020華岡兒童夏令營  MV流行街舞TWICE- LIKEY',
#        '昆蟲星球大發現2020華岡兒童夏令營 夏日蟲蟲培養家', '呆萌寵物小獸醫2020華岡兒童夏令營 實習小獸醫',
#        '小小料理達人2020華岡兒童夏令營 西歐下午茶(Low Tea)',
#        '造型設計師2020華岡兒童夏令營 我的生活日常品(皮件+排鑽+手縫吊飾)',
#        'Coding Maker2020華岡兒童夏令營 創客自造者-智能紅外線/額溫槍',
#        '活力少年營隊APCS大學程式設計先修培訓 實力養成-基礎班。(第二梯次)',
#        '小小香氛師2020華岡兒童夏令營 彩色香味Life', '福爾摩斯解謎遊戲2020華岡兒童夏令營 我會變魔數',
#        '壓克力新創畫家2020華岡兒童夏令營 創意技法畫世界',
#        '全日制 BTS 小小達人夏令營(第二梯)：自造小達人我最棒（確定開班!） 邊玩邊學，快樂學習',
#        '律動英語 IL+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#        '多色染創作工作坊2020華岡兒童夏令營 夏日的繽紛染織創作時光', '露營小玩家2020華岡兒童夏令營 泰雅獵人彩虹冒險趣',
#        '兒童全腦開發訓練師認證輔導初階班 含專注力訓練師資培訓18小時', '專注力訓練師資培訓班 有了專注力，學習將事半功倍',
#        '創客異想世界2020華岡兒童夏令營 星際光劍 Maker自造者',
#        "兒童舞蹈教室 2020華岡兒童夏令營  MV流行街舞BLACKPINK- AS IF IT'S YOUR LAST",
#        '開口說話不害怕兒童自信演說表達營 報名課程贈送午餐已額滿',
#        'SCRATCH程式設計兒童夏令營 基礎班 第二期 Fun手玩程式，動畫遊戲設計初體驗',
#        '小小植物觀察家2020華岡兒童夏令營 用五感實踐園藝綠色生活', '小小料理達人2020華岡兒童夏令營 皇家點心派對',
#        '兒童美術大師2020華岡兒童夏令營 拉斐爾500年', '小紳士小淑女2020華岡兒童夏令營 品格養成x禮儀儀態',
#        '德語Ä柏林2020華岡兒童夏令營 "藝"起學德語(旅遊篇)',
#        'micro:bit 2020華岡兒童夏令營  程式營-AI機器偵查戰警',
#        '指尖藝術繪粉彩2020華岡兒童夏令營 暑假的希望之光',
#        '律動英語MQ+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#        '小小全美語音樂劇表演課-受孩子們喜愛的音樂劇歌曲故事精選 8月Frozen冰雪奇緣班',
#        '小小勇士野外求生營2020華岡兒童夏令營 海賊王野外定向尋寶囉!',
#        '大自然生態學苑2020華岡兒童夏令營 草山小學堂-擎天崗巡禮路線', '小小魔術師2020華岡兒童夏令營 魔術師的考驗',
#        '兒童舞蹈教室 2020華岡兒童夏令營  踢踏舞好好玩-Sing Sing Sing 搖擺吧!踢踏舞',
#        '兒童理財營2020華岡兒童夏令營 富孩子養成計畫', '戳戳樂羊毛氈2020華岡兒童夏令營 企鵝烘焙坊',
#        '烏克麗麗輕鬆彈2020華岡兒童夏令營 彈彈唱唱樂一夏', '小小背包客2020華岡兒童夏令營 藝文風卡麥拉旅行',
#        '小小料理達人2020華岡兒童夏令營 米其林小廚師', '兒童珠寶設計師2020華岡兒童夏令營 女孩的手作珠寶(人魚公主的星空)',
#        '經典手工餅乾禮盒製作2020華岡兒童夏令營 洋果子禮盒烘焙營',
#        '全日制 BTS 小小達人夏令營(第三梯)：探索小達人我最棒（確定開班!） 邊玩邊學，快樂學習',
#        '律動英語RV+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)',
#        '創意Mini車床大師2020華岡兒童夏令營 百變文具機器人',
#        '遊戲英語劇團2020英語口語表達與戲劇夏令營 Robin Hood 羅賓漢',
#        '手繪時尚服裝畫2020華岡兒童夏令營 Kids Fashion Drawing-2020流行最經典篇',
#        '兒童舞蹈教室 2020華岡兒童夏令營  MV流行街舞GFRIEND-Me gustas tu',
#        '曠世奇才科學家2020華岡兒童夏令營 食尚玩家科學營', '輕水彩繪畫日記2020華岡兒童夏令營 快樂的生活點滴',
#        '小小料理達人2020華岡兒童夏令營 義式主廚私房菜', '兒童美術大師2020華岡兒童夏令營 素描就是這麼好玩',
#        '魔法麥克風2019華岡兒童夏令營 小小主持人口才養成遊戲營', '手作烘培1號店2020華岡兒童夏令營 手感溫度vs滋味好禮',
#        '小時光手工皂2020華岡兒童夏令營 天然手工皂高階小達人',
#        '律動英語WZ+體適能2020華岡兒童夏令營 劍橋兒童英語(全美語環境教學)', '兒童全腦開發訓練師認證輔導進階班',
#        '國小數學中年級師資培訓班 資深國小數學老師，帶你輕鬆教數學',
#        '國語正音教學師資培訓 業界最完整正音教學全修課程讓你現學現用沒煩惱',
#        'SCRATCH程式設計師資培訓班免費說明會 掌握程式語言掌握未來趨勢！',
#        'SCRATCH程式設計師資培訓班免費說明會 掌握程式語言掌握未來趨勢！', '兒童全腦開發訓練師認證輔導免費課程體驗及說明會',
#        '兒童課後照顧服務人員職前訓練課程 符合資格，結訓當日立即領取新北市政府教育局證書今年最後一梯次唷!!',
#        '多元智能檢測分析師認證輔導免費課程說明會 在不景氣中開創大好商機!!',
#        '兒童全腦開發訓練師認證輔導初階班 含專注力訓練師資培訓18小時', '專注力訓練師資培訓班 有了專注力，學習將事半功倍',
#        'SCRATCH程式設計師資培訓班 平日晚間班', '感覺統合運動遊戲人員培訓班理論實務兼具 (原"感覺統合教學師資培訓班")',
#        'SCRATCH程式設計師資培訓班 假日白天班', '多元智能檢測分析師認證輔導 ～在不景氣中開創大好商機!!',
#        '兒童全腦開發訓練師認證輔導兒童發展理論與實務 含班級經營與親師溝通',
#        'TAYL兒童美術師資認證輔導-台中班 超夯美術老師認證課程，歡迎加入美術老師行列',
#        '英語繪本師資培訓班 超強兒童繪本講師親自授課',
#        '閩南語語言能力認證考試輔導班 歡迎聽懂台語、對台語推廣有興趣、不限國籍年齡報名參加', '國小數學高年級師資培訓班',
#        'CWT兒童作文師資認證輔導', '手工皂專業師資認證研習營 教學創業無往不利', '兒童全腦開發訓練師認證輔導進階班',
#        '兒童全腦開發訓練師認證輔導兒童發展理論與實務 含班級經營與親師溝通',
#        '閩南語語言能力認證考試加強班 針對想考B2級閩南語語言能力做加強培訓喔!!',
#        '劍橋兒童英語家教班免費試上與說明會 比請家教更好的品質！比上補習班更漂亮的價格！',
#        '藥草女巫手作-金錢魔法薰香粉 學費含材料費', '液體皂時光 潔身抗菌系列', 'Pure soap手工皂快樂學',
#        '文青銀匠體驗 GIFTIE新金工銀黏土飾品教學', '小小銀匠體驗 GIFTIE新金工銀黏土飾品教學',
#        '壓克力同樂繪主題3 [晚上班] <再1位就開班> 全新單元 歡迎舊生續報，也很歡迎新生喔，零基礎可！',
#        '露比的點心茶會｜仿真甜點飾品手作', '水性色鉛筆彩繪｜風景小藝思 只剩2個名額',
#        '藥草女巫手作-淨化保護魔法噴霧 學費含材料費', '布克生活插畫課明信片小旅行-田園北海道 [週二下午班]',
#        '居家整理收納術確定開班 整理心 整理家 充滿愛', '占星不求人初階占星學 從零開始學占星',
#        '生活速寫轉角咖啡廳．城市巷弄．自己的房間', '藥草女巫手作-愛情魔法油 學費含材料費',
#        '七夕催桃花密技：就要以貌取人！懂手面相才能找好對象 加映生肖&風水增進桃花、抓住幸福', '夏日清涼飲品蠟燭 全新企劃',
#        '紫微斗數初階入門(周日上午班) 輕鬆學會解讀命盤=主宰你的人生', '浪漫風情小夜燈 NEW蠟材創作',
#        '免澆水仙人掌創意蠟燭 NEW 辦公室療癒蠟燭', '自製金箔透明溫感「花」心思變色唇膏 周末療癒夜', '繽紛果醬蠟燭 好評加開',
#        '書法研習班 免費講座', '書法研習班 免費講座', '日本和諧粉彩準指導師培訓 平日班',
#        '布克生活插畫課明信片小旅行-田園北海道 [週二晚上班]', '輕鬆學繪．輕水彩 小花先生',
#        '紫微斗數初階入門(平日晚上班) 輕鬆學會解讀命盤=主宰你的人生',
#        '一次學會易經占卜 透視人生的智慧寶典，現在報名還有好禮相送！', '大天使神諭占卡 簡單上手的占卜工具，結合啟發及靜⼼',
#        '兒童收納引導術', 'UV樹脂設計-金屬框造型 (基礎班) 週六下午', '書法研習班', '書法研習班',
#        '就愛玩混搭─彩墨與色鉛的雙重奏', 'Pure soap寶石皂創意 浪漫時光', '渲染‧玩皂B班 午後時光',
#        '凡爾賽玫瑰蛋糕皂 NEW 韓式擠花技巧大進擊', 'UV樹脂設計-水晶花球耳環 (中階班) 週三晚上',
#        '水性色鉛筆彩繪｜美食小藝思 （第4期）新菜單！',
#        '當代金工創作–用故事來製作物件 [上午班] mental work with in metal work',
#        '速繪我的旅遊時代漫遊歐洲 輕柔剔透的輕水彩技法，方便攜帶及且能快速完成', '寵愛肌膚保養品DIY NEW',
#        'Pure soap手工皂快樂學', '超寫實袖珍食玩月圓之夜伴手禮', '漫畫創作職涯多元發展 結合職場與商業',
#        'Pure soap手工皂快樂學 午后時光', '占星不求人進階占星學',
#        '雷諾曼牌卡占卜初階班 歐洲百年皇家御用的占卜法今年唯一一梯，欲報從速',
#        '輕鬆學會塔羅牌塔羅牌78張新星班 奠定塔羅奧義基礎，開啟心靈覺察力', 'Pure soap寶石皂創意 周末時光',
#        '仿真場景模型製作｜台灣街角情境', '漫畫創作職涯多元發展 結合職場與商業',
#        'Just for U 百變*皂*型 幸福感包裝 百變*皂*型', '整理收納諮詢師認證 全台首張職能導向認證',
#        '超寫實袖珍食玩眷村的家鄉味 乾麵or雞肉飯套餐，你今天想吃哪一道?', '雷諾曼牌卡占卜進階班 歐洲百年皇家御用的占卜法進階班',
#        '塔羅牌進階實戰班 牌陣實例導引，養成實際解牌能力', '超寫實袖珍食玩溫暖宅味夾心吐司',
#        '圓圈繪畫基礎導師認證課程 已額滿，可來電預約下梯次 ☞ 7/11前報名享早鳥價省$1,500元！',
#        '運筋骨專業入門班(下午班) 摸骨技術大解密!! 自然而然就會的手底下真功夫',
#        '運筋骨專業入門班(晚上班) 摸骨技術大解密!! 自然而然就會的手底下真功夫', '芳療聊心話-色彩與脈輪 精油五感很靜心',
#        'NAHA美國整體芳療師認證-高階I學科 成為專業芳療師', 'HOME SPA香氛養生之道 身心合一，動靜結合再一位開課',
#        '本草王的膝關節名方論 教你如何改善膝關節退化等問題', 'DS嬰幼兒動能知覺瑜珈檢定課程暑期夜間班',
#        '兒童及青少年表達性藝術療育實務與應用 療育系名師童玉娟老師親自授課',
#        '免費課程說明會-銀髮族藝術陪伴與自我照顧 失落情緒議題 & 樂齡藝術陪伴師資認證',
#        'NAHA美國整體芳療師認證-初階II 專業芳療進階', '母嬰照護認證聯合說明會',
#        'NAHA美國整體芳療師認證-初階I 踏入專業芳療的第一步,小班制',
#        '艾莉老師的靜心哈達瑜珈（Hatha Yoga）週三晚上班 找回丟失的靜心和肌肉',
#        '兒少藝術療育：跟榮格的藝術視野學情緒教養 藝術教育博士、專業藝術治療師徐玟玲老師親授',
#        '艾莉老師的靜心哈達瑜珈（Hatha Yoga）周二下午班 找回丟失的靜心和肌肉',
#        '艾莉老師的和緩流暢瑜珈（Flow Yoga）周二下午班 喚醒你的核心與肌力',
#        '艾莉老師的午休伸展瑜珈～周二午休班 消除肌肉緊繃，回復柔軟線條',
#        'NAHA美國整體芳療師認證-初階I 踏入專業芳療的第一步<名額有限,精緻小班>', '母嬰照護認證聯合說明會',
#        '失落情緒議題銀髮族藝術陪伴與自我照顧', '艾莉老師的午休舒心瑜珈～周一午休班', '月子管理師培訓班初階班 平日密集班',
#        'BSS寶寶音樂手語檢定證照課程 讓還不會說話的寶寶也能與您溝通', '專業經絡師培訓營 免費說明會 一技之長在手無可取代價值',
#        '香氛紓壓活絡術 變身芳香舒壓達人', 'NAHA美國整體芳療師認證-初階II 專業芳療進階',
#        '銀髮族芳療與經絡按摩照護班 可累計長照積分12點結合中西方照護的養生方式，舒緩老化或慢性疾病',
#        '芳香輕療癒-十二時辰養生法 幫身體「在正確時間做正確的事」', '從心彩繪曼陀羅-體驗工作坊 沒有畫畫基礎也可以參加!!',
#        '月子管理師培訓班進階班 平日密集班', '芳香輕療癒-斷捨離，減法過新生 香氛開運小妙方',
#        '從心彩繪曼陀羅-體驗工作坊 沒有畫畫基礎也可以參加!!',
#        '兒童及青少年正念曼陀羅繪畫療育職能培訓 療育系名師童玉娟老師親自授課', '專業經絡師培訓營 週日班班爆滿，可回訓',
#        '兒童音樂療育實務與應用', 'NAHA專業芳療師Lv2回訓CES時數 中醫芳療助好眠', '新生兒健康管理師',
#        'NAHA美國整體芳療師認證-初階I 踏入專業芳療的第一步', '園藝治療師培訓班-新講義上線 今年最後一梯',
#        '從心彩繪曼陀羅-體驗工作坊 沒有畫畫基礎也可以參加!!', 'CBM嬰幼兒按摩檢定課程平日早鳥班',
#        '芳香輕療癒-滿足，養好足 看腳知健康', '產後健康管理師完整產後泌乳照護實作 假日密集班',
#        'NAHA專業芳療師Lv2回訓CES時數 中醫芳療助好眠', '從心彩繪曼陀羅-體驗工作坊 沒有畫畫基礎也可以參加!!',
#        '芳療聊心話-色彩與脈輪 精油五感很靜心', '香氛紓壓活絡術 變身芳香舒壓達人',
#        '產後健康管理師含產後泌乳照護實作 平日密集班', '從心彩繪曼陀羅初階工作坊 沒有畫畫基礎也可以參加!!',
#        'NAHA美國整體芳療師認證-初階I 踏入專業芳療的第一步<精緻小班，名額有限>', '新生兒健康管理師 假日密集班',
#        '樂齡藝術陪伴師資認證', '芳香輕療癒-面相氣色看五行 透過五官及面色檢視身體狀態', 'CBM嬰幼兒按摩檢定課程假日早鳥班',
#        'DS嬰幼兒動能知覺瑜珈檢定課程假日午茶班', '月子管理師培訓班初階班 平日密集班',
#        'NAHA美國整體芳療師認證-初階I 踏入專業芳療的第一步', '從心彩繪曼陀羅進階工作坊',
#        '芳香輕療癒-斷捨離，減法過新生 香氛開運小妙方', '月子管理師培訓班進階班 假日密集班',
#        '英式銀髮族芳香觸撫按摩入門班 英國TAS芳療+美國SCRIBE觸撫按摩手法',
#        "一對一寵物基礎美容 3小時學會洗澡與基礎修剪！上課地點：p'adore寵愛創新孵育基地",
#        "一對二寵物基礎美容 歡迎二位學員攜帶1位毛孩一起上課！上課地點：p'adore寵愛創新孵育基地",
#        "一對一寵物進階美容 本課程適合有寵物美容基礎者或上過基礎課者。上課地點：p'adore寵愛創新孵育基地",
#        '寵膳食育師基礎職能證照密集班 [7月梯次確定開班]歡迎參加！ 上課地點：p’adore寵愛創新孵育基地',
#        '寵物按摩師基礎實務班(週三晚上班) [最後3名！] ★本課程通過台北市動保處10小時專業人士專業訓練時數認可 ★ 整合寵物按摩原理及預防醫學觀念，延緩毛孩肌肉與關節老化秘訣',
#        '寵物教養師基礎證照班:犬貓特殊需求養護(進階班) 新增貓咪照護 & 貓咪鮮食單元 ➤6/7基礎班上完後可銜接本班 ➤本班也可單獨報名',
#        '寵物按摩師基礎實務班(假日班) <再2位就開班> ★本課程通過台北市動保處10小時專業人士專業訓練時數認可★ 整合寵物按摩原理及預防醫學觀念，延緩毛孩肌肉與關節老化秘訣',
#        '寵物照護員職能培訓班-進階班-台北班 本課程為7/4基礎班接續課程，符合台北市動保處專任人員訓練課程200小時，採認時數30小時',
#        '基礎訓貓課程 建立與貓咪溝通的橋樑 上課地點：p’adore寵愛創新孵育基地',
#        '寵物臨終服務師職能培訓班-台中班 本課程通過勞動力發展署職能導向課程品質ICAP認證',
#        '寵膳食育師基礎職能證照班 8月梯次[確定開班]歡迎參加！[8月梯次確定開班]歡迎參加！  上課地點：p’adore寵愛創新孵育基地',
#        '預約登記寵物照護員職能培訓班-台北班 此為下半年台北班寵物照護員預約頁面，課程上架將發簡訊主動通知您！',
#        '寵愛毛小孩清潔一把罩固體皂+液體皂+噴霧 午后時光', '寵物教養師基礎證照班:犬貓基礎養護(基礎班) ➤可銜接11/29進階班',
#        '漢克老師的狗狗行為基礎訓練 別亂教你的狗！讓20年實務經驗漢克老師，教你正確訓練方法',
#        '寵物按摩師進階應用班 培養針對不同的個案狀況進行整合及安排運動計畫，並結合最新貼紮技術',
#        '寵物臨終服務師職能培訓班-高雄班 本課程通過勞動力發展署職能導向課程品質ICAP認證',
#        '預約登記寵物臨終服務師職能培訓班-台中班 預計年底開課，課程上架將以簡訊通知您！',
#        '寵物教養師基礎證照班:犬貓特殊需求養護(進階班) 新增貓咪照護 & 貓咪鮮食單元 ➤9/20基礎班上完後可銜接本班 ➤本班也可單獨報名',
#        '預約登記寵物臨終服務師職能培訓班-台北班 預計明年年初開課，課程上架將以簡訊通知您！',
#        '預約登記寵物照護員職能培訓班-台中班 此為明年台中班寵物照護員預約頁面，課程上架將發簡訊主動通知您！',
#        '預約登記寵物照護員職能培訓班-高雄班 此為明年高雄班寵物照護員預約頁面，課程上架將發簡訊主動通知您！',
#        '實用越南語V1-週二班', '實用越南語V1-週六班', '實用印尼語N1-週四班', '多益實戰班中級、中高級',
#        '預約登記德語入門A1-1 德語，打開通往歐洲文化之門',
#        '劍橋兒童英語家教班免費試上與說明會 比請家教更好的品質！比上補習班更漂亮的價格！',
#        '室內設計乙級題型分析應考衝刺班(三六晚班) 重考生必上!!! 針對公告題型快速加強應考訣竅',
#        '光在金工珠寶私塾手作輕珠寶課程 一日金工體驗', '光在金工珠寶私塾魅影琺瑯飾品課程 一日金工體驗',
#        '光在金工珠寶私塾金工生活小品課程 琺瑯銅盤(一日金工體驗)', '光在金工珠寶私塾金工生活小品課程 蝕刻鍛敲銅盤(一日金工體驗)',
#        '室內給水排水通氣系統規劃設計 從基礎到專業本課程可以累積300分的技師訓練積分',
#        '引爆室內設計接案商機實務 室內設計如何走向永續經營6小時學會接案的「內外」心法！',
#        'VRay for Sketchup渲染 專業須不斷學習 快速打造真實場景贏得客戶青睞!',
#        '光在金工珠寶私塾手作輕珠寶課程 一日金工體驗', '光在金工珠寶私塾魅影琺瑯飾品課程 一日金工體驗',
#        '光在金工珠寶私塾金工生活小品課程 琺瑯銅盤(一日金工體驗)', '光在金工珠寶私塾金工生活小品課程 蝕刻鍛敲銅盤(一日金工體驗)',
#        '廚房廚具設計人才速成班 21小時快速掌握「材質×格局×預算」', '光在金工珠寶私塾手作輕珠寶課程 一日金工體驗',
#        '光在金工珠寶私塾魅影琺瑯飾品課程 一日金工體驗', '光在金工珠寶私塾金工生活小品課程 琺瑯銅盤(一日金工體驗)',
#        '光在金工珠寶私塾金工生活小品課程 蝕刻鍛敲銅盤(一日金工體驗)',
#        '室內裝修工程管理乙級技術士全修班周二四班 109年錄取率達90% 重考生憑准考證或成績單可再減免2000元',
#        'SketchUp室內超精細建模實務技術班 習得隱藏高階密技，邁向PRO級的室內設計師養成',
#        '室內裝修審查業務辦理與案例應用 24小時全面了解室內裝修審查要訣', '12吋人偶公仔立體模型設計 知名公仔品牌創作人蔣正廷',
#        '光在金工珠寶私塾手作輕珠寶課程 一日金工體驗', '光在金工珠寶私塾魅影琺瑯飾品課程 一日金工體驗',
#        '光在金工珠寶私塾金工生活小品課程 琺瑯銅盤(一日金工體驗)', '光在金工珠寶私塾金工生活小品課程 蝕刻鍛敲銅盤(一日金工體驗)',
#        'VRay for Sketchup渲染 專業須不斷學習 快速打造真實場景贏得客戶青睞!',
#        '室內裝修工程管理乙級技術士術科衝刺班周日班 109年錄取率達90% 重考生憑准考證或成績單可再減免2000元',
#        '光在金工珠寶私塾手作輕珠寶課程 一日金工體驗', '光在金工珠寶私塾魅影琺瑯飾品課程 一日金工體驗',
#        '光在金工珠寶私塾金工生活小品課程 琺瑯銅盤(一日金工體驗)', '光在金工珠寶私塾金工生活小品課程 蝕刻鍛敲銅盤(一日金工體驗)',
#        '光在金工珠寶私塾手作輕珠寶課程 一日金工體驗', '光在金工珠寶私塾魅影琺瑯飾品課程 一日金工體驗',
#        '光在金工珠寶私塾金工生活小品課程 琺瑯銅盤(一日金工體驗)', '光在金工珠寶私塾金工生活小品課程 蝕刻鍛敲銅盤(一日金工體驗)',
#        '藝術經紀人培訓免費分享會 藝術經紀好好玩', '藝術經紀人培訓 成為藝術經紀人最佳途徑',
#        '藝術經紀人培訓免費分享會 藝術經紀好好玩', '婚禮企劃主持實務課 結合企劃與主持，串起一場愛與幸福的完美婚禮',
#        '天然精油調香藝術 專業班 譜香、修香和說香', '天然精油調香藝術初階班 學費含材料費!',
#        '楊比比攝影人2020 數位攝影暗房攻略 基礎班 確定開班', '美甲控必學！凝膠指甲 午後時光小班教學名額有限',
#        'Color4 IMAGE 專業時尚品味顧問培訓(假日班) 基礎培訓班--日本JPCA專業個人色彩分析師 + 國際專利Color4 IMAGE 品味座標法 雙認證',
#        'Color4 IMAGE 專業時尚品味顧問培訓(密集班) 基礎培訓班--日本JPCA專業個人色彩分析師 + 國際專利Color4 IMAGE 品味座標法 雙認證',
#        '策展經理人培訓', '天然精油調香藝術初階班 學費含材料費!',
#        'Color4 IMAGE個人色彩分析師培訓 日本JPCA色彩技能國際認證(假日密集班)',
#        'Color4 IMAGE個人色彩分析師培訓 日本JPCA色彩技能國際認證(平日密集班)',
#        '天然精油調香藝術進階班 調香更得心應手! 渾然天成!', '天然精油調香藝術進階班 調香更得心應手! 渾然天成!',
#        '天然精油調香藝術高階班 調配出一瓶專屬的香氣身份證', '從分析到機器學習:Level_Ⅰ NO CODE 不寫程式機器學習',
#        '從分析到機器學習 NO CODE 不寫程式機器學習',
#        'AI/BIG DATA大數據技能養成班 第11期熱烈招生中 成為最搶手的關鍵人才', 'Python 數據資料分析師入門班',
#        'OpenCV影像辨識與機器學習', '白帽駭客認知班 AI/Big Data技能養成班系列課程:確定開班',
#        '區塊鏈入門實務班 AI/Big Data技能養成班系列課程:確定開班', 'Java菁英養成專班',
#        'Python 數據資料分析師入門班', 'CMA國際管理會計師證照考照免費課程說明會 全球管理會計及財務管理領域權威證照',
#        'HR人資商學院第二屆︱HR Growth Hacker',
#        'CMA國際管理會計師證照考照 Wiley CMA 教材+48小時面授課程(本期加贈20小時考前輔導)', '商務談判第一次就上手',
#        '策略性人力資源管理師認證班', '會計入門 抓出營運問題，制訂有效決策',
#        '溝通跨越力養成班 從六歲到七八十歲，從小孩到公司老闆，都能有效溝通！再兩位開班', '員工心理諮商輔導人員認證班',
#        '視覺圖像設計與溝通表達', '休閒農業經營管理班 政府補助：$2880，參訓學員自行負擔：$720', '財務報表分析全修班',
#        '美國註冊會計師(CPA)證照班', '美國註冊會計師(CPA)證照班-舊生專案FAR',
#        'AVM作業價值管理師 破除成本迷思，掌握企業決策 第二期熱烈招生中',
#        'BCC國際認證專業教練國際證照培訓班－台北班 ★啟動潛能激發、邁向致勝職涯★',
#        '英國City & Guilds行銷管理師(銷售)國際證照輔考課程', '商務談判第一次就上手',
#        'CMA國際管理會計師證照考照 Wiley CMA 教材+48小時面授課程(本期加贈20小時考前輔導)',
#        '會計入門 抓出營運問題，制訂有效決策', '財務報表分析全修班', 'CGAP總務採購管理師認證班-台中班',
#        'SEO策劃師培訓認證 數位行銷專家的第一步', '英國City&Guilds顧客關係管理師(顧客服務)證照課程',
#        'CCE國際證照 BCC國際認證費 BCC國際證照費', 'Smart理財股票策略初階班  大股票論壇-1 進場之道 : 5堂課',
#        'ETF新手變行家免費分享會', 'ETF新手變行家免費分享會', 'ETF新手變行家初階班 假日班', 'ETF新手變行家全修班',
#        '共有土地開發 開發處份與分割實務', 'Smart理財股票策略: 布局防疫新商機の菁英投資高峰論壇',
#        '2天讓您學會法拍屋致富實戰', '外匯致勝方程式 掌握外匯市場投資致勝關鍵', '買屋價值鑑定實務班 10小時練就「好宅」眼光力',
#        'ETF新手變行家免費分享會', 'ETF新手變行家免費分享會', 'ETF新手變行家初階班 平日班', 'ETF新手變行家中階班',
#        '股市投資實戰初階 杜老師帶你判斷未來走勢', '不動產法律實戰班 排除地上物及共有土地處分法律實戰',
#        '第一次買房就上手 最佳買房成功術', 'ETF新手變行家免費分享會', 'ETF新手變行家免費分享會',
#        'ETF新手變行家高階班', '外匯致勝方程式 掌握外匯市場投資致勝關鍵', '第一次買房就上手 最佳買房成功術',
#        '股市投資實戰初階 杜老師帶你判斷未來走勢'], dtype=object)

# %%
df['web'] = 'GoGoCourse購購課'
df['tech'] = np.nan
df['lan'] = np.nan
df['bz'] = np.nan
df['others'] = True
df['type'] = 'offline'
df['all_city'] = np.nan
df['taipei_dist'] = np.nan
df['address'] = np.nan
df['weekday'] = False
df['weekends'] = False
df['start_time'] = np.nan
df['end_time'] = np.nan
df = df[['web','title','hours','price','time','location','today','tech','lan','bz','others','type','all_city','taipei_dist','address','weekday','weekends','start_time','end_time']]

# ----------tech---------------------------

for i in range(len(df)):
    if 'Python' in df['title'].values[i]:
        df.loc[i,'tech'] = 'Python'
        df.loc[i,'others'] = False
    elif 'Java' in df['title'].values[i]:
        df.loc[i,'tech'] = 'Java'
        df.loc[i,'others'] = False
    elif '網頁開發' in df['title'].values[i]:
        df.loc[i,'tech'] = 'WebDesign'
        df.loc[i,'others'] = False
    elif 'Linux' in df['title'].values[i]:
        df.loc[i,'tech'] = 'Linux'
        df.loc[i,'others'] = False
    elif 'C#' in df['title'].values[i]:
        df.loc[i,'tech'] = 'C#'
        df.loc[i,'others'] = False
    elif 'R' in df['title'].values[i]:
        df.loc[i,'tech'] = 'R'
        df.loc[i,'others'] = False
    elif 'C++' in df['title'].values[i]:
        df.loc[i,'tech'] = 'C++'
        df.loc[i,'others'] = False
    elif '資料庫' in df['title'].values[i]:
        df.loc[i,'tech'] = 'Database'
        df.loc[i,'others'] = False
    elif '網路工程' in df['title'].values[i]:
        df.loc[i,'tech'] = 'Network'
        df.loc[i,'others'] = False
    else:
        df.loc[i,'tech'] = np.nan
        
# -------lan-----------------------
        
for j in range(len(df)):
    if '英語' in df['title'].values[j]:
        df.loc[j,'lan'] = 'ENG'
        df.loc[j,'others'] = False
    else:
        df.loc[j,'lan'] = np.nan
        
# -------bz-------------------

for l in range(len(df)):
    if '商務' in df['title'].values[l]:
        df.loc[l,'bz'] = 'MGMT'
        df.loc[l,'others'] = False
    elif '管理' in df['title'].values[l]:
        df.loc[l,'bz'] = 'MGMT'
        df.loc[l,'others'] = False
    elif '證照' in df['title'].values[l]:
        df.loc[l,'bz'] = 'LIS'
        df.loc[l,'others'] = False
    elif '財務' in df['title'].values[l]:
        df.loc[l,'bz'] = 'FIN'
        df.loc[i,'others'] = False
    elif '會計' in df['title'].values[l]:
        df.loc[l,'bz'] = 'FIN'
        df.loc[l,'others'] = False
    elif '理財' in df['title'].values[l]:
        df.loc[l,'bz'] = 'FIN'
        df.loc[i,'others'] = False
    elif 'ETF' in df['title'].values[l]:
        df.loc[l,'bz'] = 'FIN'
        df.loc[l,'others'] = False
    elif '外匯' in df['title'].values[l]:
        df.loc[l,'bz'] = 'FIN'
        df.loc[l,'others'] = False
    elif '股市投資' in df['title'].values[l]:
        df.loc[l,'bz'] = 'FIN'
        df.loc[l,'others'] = False
    else:
        df.loc[l,'bz'] = np.nan
        
        
# -------location、address-------------------

for k in range(len(df)):
#   taipei
    if '大安中心' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市大安區信義路四段1號3樓'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '大安區'
    elif '華岡' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市大安區信義路四段1號3樓'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '大安區'
    elif '福華' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市大安區新生南路三段三十號'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '大安區'
    elif 'investU線上社大 台北教室' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市信義區松山路421號16樓之2'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '信義區'
    elif '為你而讀' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市大安區和平東路一段75巷2-1號'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '大安區'
    elif '臺北市青少年發展處' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市仁愛路一段17號'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '中正區'
    elif '華岡' and '福華' in df['location'].values[k]:
        df.loc[k,'all_city'] = 'taipei'
    elif '身障資源中心' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市中山區長安西路5巷2號'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '中山區'
    elif '台北市萬華區艋舺大道140號' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市萬華區艋舺大道140號'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '萬華區'
    elif '台灣文創訓練中心' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市中山區松江路131號'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '中山區'
    elif '台北市大同區' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市大同區迪化街一段32巷14號2樓'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '大同區'
    elif '台北市大安區106永康街75巷8號5樓之2' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市大安區106永康街75巷8號5樓之2'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '大安區'
    elif '台北市大安區' in df['location'].values[k]:
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '大安區'
    elif '創世紀國際不動產管理顧問有限公司' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市信義區信義路四段415號8樓之5'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '信義區'
    elif '台北市中山區長安東路二段92號2樓' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市中山區長安東路二段92號2樓'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '中山區'
    elif '台北市南京東路四段2號1-10號店鋪' in df['location'].values[k]:
        df.loc[k,'address'] = '台北市南京東路四段2號1-10號店鋪'
        df.loc[k,'all_city'] = 'taipei'
        df.loc[k,'taipei_dist'] = '松山區'
    elif '淡江大學台北校區' in df['location'].values[k] and '台灣文創訓練中心' in df['location'].values[k]:
        df.loc[k,'all_city'] = 'taipei'
#   taichung
    elif '台中新創館' in df['location'].values[k]:
        df.loc[k,'address'] = '台中市西區台灣大道2段2號3F-3'
        df.loc[k,'all_city'] = 'taichung'
    elif '台中東海大學' in df['location'].values[k]:
        df.loc[k,'address'] = '臺中市臺灣大道四段1727號管理大樓 東海大學第二教學區'
        df.loc[k,'all_city'] = 'taichung'
#   kaohsiung
    elif '高雄信義館' in df['location'].values[k]:
        df.loc[k,'address'] = '高雄市苓雅區中正二路175號13樓之3'
        df.loc[k,'all_city'] = 'kaohsiung'
    elif '' in df['location'].values[k]:
        df.loc[k,'address'] = np.nan
        df.loc[k,'all_city'] = np.nan
    elif '高雄市三民區博愛一路366號14樓' in df['location'].values[k]:
        df.loc[k,'address'] = '高雄市三民區博愛一路366號14樓'
        df.loc[k,'all_city'] = 'kaoshiung'
    else:
        df['location'].values[k] = df.loc[k,'address']
        
# # # -----weekdays------------------

for n in range(len(df)):
    if '六' in df['time'].values[n] or '日' in df['time'].values[n]:
        df.loc[n,'weekends'] = True
    elif '一' in df['time'].values[n] or '二' in df['time'].values[n] or '三' in df['time'].values[n] or '四' in df['time'].values[n] or '五' in df['time'].values[n]:
        df.loc[n,'weekday'] = True
    else:
        df.loc[n,'weekends'] = False
        df.loc[n,'weekday'] = False
        
# ------start_time/end_time-----------
# Out:
# /Users/t3019ein/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
data = df.drop(['time','location'], axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   web          364 non-null    object
#  1   title        364 non-null    object
#  2   hours        364 non-null    float32
#  3   price        364 non-null    int64
#  4   today        364 non-null    object
#  5   tech         19 non-null     object
#  6   lan          9 non-null      object
#  7   bz           54 non-null     object
#  8   others       364 non-null    bool
#  9   type         364 non-null    object
#  10  all_city     351 non-null    object
#  11  taipei_dist  343 non-null    object
#  12  address      348 non-null    object
#  13  weekday      364 non-null    bool
#  14  weekends     364 non-null    bool
#  15  start_time   0 non-null      float64
#  16  end_time     0 non-null      float64
# dtypes: bool(3), float32(1), float64(2), int64(1), object(10)
# memory usage: 39.6+ KB

# %%
aaa = df['time'].values[1]

# %%
aaa1 = aaa.split(":")
aaa1[0].replace("日","")+":00"
# Out:
# '10:00'

# %%
aaa1[1].replace('00~','')+':00'
# Out:
# '17:00'

# %%
d = df['time'].values[0].split("~")
d2 = d[1].split(';')
d2
# Out:
# ['15:30']

# %%
d[0][0]
# Out:
# '四'

# %%
d1 = df['during'].values[0].split('~')

# %%
df['end_time']
# Out:
# 0      40-16:00
# 1      40-16:00
# 2      40-16:00
# 3      40-16:00
# 4      40-16:00
#          ...
# 372    40-16:00
# 373    40-16:00
# 374    40-16:00
# 375    40-16:00
# 376    40-16:00
# Name: end_time, Length: 377, dtype: object

# %%
for n in range(len(df)):
    df['time'].values
#     if '六' or '日' in df['time'].values[n]:
#         df.loc[n,'weekends'] = True
    if '一' or '二' or '三' or '四' or '五' in df['time'].values[n]:
        df.loc[n,'weekday'] = True
    else:
        df.loc[n,'weekends'] = False
        df.loc[n,'weekday'] = False

# %%
df
# Out:
#                web                                    title  hours  price  \
# 0    GoGoCourse購購課  英國巴哈情緒花精&美國NAHA芳療師 聯合說明會 一次學習，全家受惠，終身受用    1.5      0
# 1    GoGoCourse購購課                    芳療精油洞悉卡諮詢工作坊 引導對話內在能量   18.0   9999
# 2    GoGoCourse購購課                             美國會計師證照課程說明會    1.0      0
# 3    GoGoCourse購購課            CDU系列聽話、問話、結構化－個案概念化 晤談力初階練功坊    6.0   4000
# 4    GoGoCourse購購課                           英國巴哈情緒花精 心靈好防疫   18.0   5888
# ..             ...                                      ...    ...    ...
# 372  GoGoCourse購購課                            ETF新手變行家免費分享會    2.0      0
# 373  GoGoCourse購購課                              ETF新手變行家高階班   10.0  69800
# 374  GoGoCourse購購課                     外匯致勝方程式 掌握外匯市場投資致勝關鍵    6.0   3600
# 375  GoGoCourse購購課                         第一次買房就上手 最佳買房成功術   20.0   8000
# 376  GoGoCourse購購課                     股市投資實戰初階 杜老師帶你判斷未來走勢   10.0   6000
#
#               time           location     today tech  lan   bz  others  \
# 0    四 14:00~15:30             華岡大安中心  20200726  NaN  NaN  NaN    True
# 1     日10:00~17:00             華岡大安中心  20200726  NaN  NaN  NaN    True
# 2      19:00~20:00             華岡大安中心  20200726  NaN  NaN  LIS   False
# 3      09-12；13-16  高雄市三民區博愛一路366號14樓  20200726  NaN  NaN  NaN    True
# 4     六10:00~17:00             華岡大安中心  20200726  NaN  NaN  NaN    True
# ..             ...                ...       ...  ...  ...  ...     ...
# 372  日 14:00-16:00             福華文教會館  20200726  NaN  NaN  FIN   False
# 373  日 10:00-16:00   investU線上社大 台北教室  20200726  NaN  NaN  FIN   False
# 374  三 19:00-22:00             華岡大安中心  20200726  NaN  NaN  FIN   False
# 375  三 19:00-21:30    公務人力發展中心-福華文教會館  20200726  NaN  NaN  NaN    True
# 376  三 13:40-16:10             華岡大安中心  20200726  NaN  NaN  FIN   False
#
#         type all_city taipei_dist             address  weekday  weekends  \
# 0    offline   taipei         大安區     台北市大安區信義路四段1號3樓     True     False
# 1    offline   taipei         大安區     台北市大安區信義路四段1號3樓    False      True
# 2    offline   taipei         大安區     台北市大安區信義路四段1號3樓    False     False
# 3    offline      NaN         NaN                 NaN    False     False
# 4    offline   taipei         大安區     台北市大安區信義路四段1號3樓    False      True
# ..       ...      ...         ...                 ...      ...       ...
# 372  offline   taipei         大安區     台北市大安區新生南路三段三十號    False      True
# 373  offline   taipei         信義區  台北市信義區松山路421號16樓之2    False      True
# 374  offline   taipei         大安區     台北市大安區信義路四段1號3樓     True     False
# 375  offline   taipei         大安區     台北市大安區新生南路三段三十號     True     False
# 376  offline   taipei         大安區     台北市大安區信義路四段1號3樓     True     False
#
#     start_time  end_time
# 0        13:00  40-16:00
# 1        13:00  40-16:00
# 2        13:00  40-16:00
# 3        13:00  40-16:00
# 4        13:00  40-16:00
# ..         ...       ...
# 372      13:00  40-16:00
# 373      13:00  40-16:00
# 374      13:00  40-16:00
# 375      13:00  40-16:00
# 376      13:00  40-16:00
#
# [377 rows x 19 columns]
