# %%
import sys
import traceback
import os
from selenium import webdriver
import time
import requests
from bs4 import BeautifulSoup as bs
from selenium.webdriver.chrome.options import Options
from tqdm import tqdm
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime 
import sqlalchemy
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    126 non-null    object
#  1   hours    126 non-null    float32
#  2   teacher  105 non-null    object
#  3   price    126 non-null    int64
#  4   today    126 non-null    object
# dtypes: float32(1), int64(1), object(3)
# memory usage: 4.6+ KB

# %%
df['title'].values[1]
# Out:
# 'Autodesk AutoCAD Mechanical 入門課程Autodesk MFG 2D AutoCAD Mechanical 入門'

# %%
df['category'] = 0
# Out:
#                                                  title  hours         teacher  \
# 0    Autodesk AutoCAD 進階應用課程Autodesk MFG 2D AutoCAD...   1.19   阮振宇 Alex Raun
# 1    Autodesk AutoCAD Mechanical 入門課程Autodesk MFG 2...   1.08   阮振宇 Alex Raun
# 2    Autodesk AutoCAD Electrical 入門課程 第1回 | 共3回Auto...   1.18    林盈呈Peter Lin
# 3      Autodesk AutoCAD 基礎課程Autodesk MFG 2D AutoCAD 基礎   1.24   阮振宇 Alex Raun
# 4           Autodesk AutoCAD Electrical 入門課程 第2回 | 共3回   1.50    林盈呈Peter Lin
# ..                                                 ...    ...             ...
# 121  Autodesk 3DS MAX 2021 Features HighlightAutode...   0.00            None
# 122                                             影片剪輯課程   0.21       田乃威 James
# 123  HyperPDM 管理者設定課程(產品開發管理)Otsuka IT 產品開發管理 Hyper...   1.18   陳淑娟Mandy Chen
# 124        Autodesk Vault 基礎課程Autodesk MFG 3D Vault 基礎   0.35        郭健偉 Ryan
# 125                          Forge【開發技巧專題】- 模型聚合和多模型管理   0.00            None
#
#      price     today  category
# 0      800  20200724         0
# 1      500  20200724         0
# 2      650  20200724         0
# 3      650  20200724         0
# 4      650  20200724         0
# ..     ...       ...       ...
# 121      0  20200724         0
# 122    250  20200724         0
# 123   1000  20200724         0
# 124    300  20200724         0
# 125      0  20200724         0
#
# [126 rows x 6 columns]

# %%
# 課程分類提出來
try:
    def wash():
        engine = create_engine(f'mysql+pymysql://allen:allen0319@192.168.56.150:3306/education?charset=utf8')
        sql = "SELECT * FROM wash;"
        df = pd.read_sql(sql,engine)
        df["hours"] = df.hours.astype("float32")
        df['price'] = df['price'].map(lambda name: name.replace(",",""))
        df['price'] = df['price'].astype('int')
    
# ----------------------------------------------------------------------

        title_content = ['Autodesk 3ds Max 基礎課程 第1回 | 共2回','Vizible基礎課程','Autodesk 3ds Max 基礎課程 第2回 | 共2回','Autodesk 3DS MAX 2021 Features Highlight','影片剪輯課程']
        title_content2 = ['HyperPDM 管理者設定課程(產品開發管理)','Autodesk Vault 基礎課程','Forge【開發技巧專題】- 模型聚合和多模型管理']
        df['web'] ='私塾堂'
        df['tech'] = np.nan
        df['lan'] = np.nan
        df['bz'] = np.nan
        df['others'] = False
        df['type'] = 'online'
        df['all_city'] = np.nan
        df['taipei_dist'] = np.nan
        df['address'] = np.nan
        df['weekday'] = False
        df['weekends'] = False
        df['start_time'] = np.nan
        df['end_time'] = np.nan
        df = df[['web','title','hours','price','today','tech','lan','bz','others','type','all_city','taipei_dist','address','weekday','weekends','start_time','end_time']]

        for i in range(len(df)):
            if 'Autodesk 3ds Max 基礎課程 第1回 | 共2回' in df['title'].values[i]:
                df.loc[i,'bz'] = 'MKT'
            elif 'Vizible基礎課程' in df['title'].values[i]:
                df.loc[i,'bz'] = 'MKT'
            elif 'Autodesk 3ds Max 基礎課程 第2回 | 共2回' in df['title'].values[i]:
                df.loc[i,'bz'] = 'MKT'
            elif 'Autodesk 3DS MAX 2021 Features Highlight' in df['title'].values[i]:
                df.loc[i,'bz'] = 'MKT'
            elif '影片剪輯課程' in df['title'].values[i]:
                df.loc[i,'bz'] = 'MKT'
            elif 'HyperPDM 管理者設定課程(產品開發管理)' in df['title'].values[i]:
                df.loc[i,'bz'] = 'MGMT'
            elif 'Autodesk Vault 基礎課程' in df['title'].values[i]:
                df.loc[i,'bz'] = 'MGMT'
            elif 'Forge【開發技巧專題】- 模型聚合和多模型管理' in df['title'].values[i]:
                df.loc[i,'bz'] = 'MGMT'
            else:
                df.loc[i,'others'] = True

        return df,engine
except Error as e:
    print(str(e))

def type_wash(df,engine):
    try:
        df.to_sql('web2_mission_completed',engine,index=False,if_exists = 'replace',
                 dtype = {
                     "web": sqlalchemy.types.Text(),
                     "title" : sqlalchemy.types.Text(),
                     "hours" : sqlalchemy.types.Float(precision=1),
                     "price" : sqlalchemy.types.INTEGER(),
                     "today" : sqlalchemy.types.Text(),
                     "tech" : sqlalchemy.types.Text(),
                     "lan" : sqlalchemy.types.Text(),
                     "bz" : sqlalchemy.types.Text(),
                     "others" : sqlalchemy.types.Boolean
                 }
                 )
    except Exception as e:
        print(str(e))

# failed-------------------------------------------------------

#     for i in range(len(df['title'])):
#         for a in cat_content:
#             if a[:] != df['title'].values[i]:
#                 row['tech'] = category_list[0]
#             else:
#                 row['category'] = category_list[1]
#             return row
#     df = df.apply(wash,axis=1)
#     df

# %%
df,engine = wash()

# %%
type_wash(df,engine)
